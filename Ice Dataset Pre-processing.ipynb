# %%
import os
import numpy as np
import xarray as xr
from pystac_client import Client

# Path to the directory containing NetCDF files
netcdf_directory = "ai4arctic-sea-ice-challenge-ready-to-train/v2/ready-to-train_train"

# STAC API client setup
client = Client.open("https://catalogue.dataspace.copernicus.eu/stac") 
collection = "SENTINEL-1"

# Initialize an empty list to collect matching filtered items
matching_items = []

# Iterate through each NetCDF file in the directory
for netcdf_file in os.listdir(netcdf_directory):
    if netcdf_file.endswith('.nc'):
        # Read the NetCDF file
        ds = xr.open_dataset(os.path.join(netcdf_directory, netcdf_file))
        
        # Calculate the bounding box
        lat_min = np.min(ds.sar_grid2d_latitude.values)
        lat_max = np.max(ds.sar_grid2d_latitude.values)
        lon_min = np.min(ds.sar_grid2d_longitude.values)
        lon_max = np.max(ds.sar_grid2d_longitude.values)

        # Define the bounding box (min_lon, min_lat, max_lon, max_lat)
        bbox = [lon_min, lat_min, lon_max, lat_max]

        # Extract the date from the scene ID in attributes (if exists)
        scene_id = ds.attrs.get('scene_id', '')  # Adjust based on actual attribute name
        date = scene_id[:8] if scene_id else ''  # Extract date part

        # Perform the Search with bbox and datetime
        search = client.search(
            collections=[collection],
            bbox=bbox,
            datetime=f"{date[:4]}-{date[4:6]}-{date[6:8]}",
            limit=100
        )

        # Fetch All Matching Items
        try:
            items = list(search.get_items())
            print(f"Found {len(items)} items matching bbox and datetime criteria for {netcdf_file}.")
        except Exception as e:
            print(f"An error occurred during the search: {e}")
            continue

        # Initialize an empty list to store filtered items
        filtered_items = []

        # Iterate through retrieved items and filter by 's1:instrument_mode' and 'processingLevel'
        for item in items:
            instrument_mode = item.properties.get('operationalMode', '')
            processing_level = item.properties.get('processingLevel', '')
            
            # Check if both conditions are met
            if instrument_mode == 'EW' and processing_level == 'LEVEL1':
                filtered_items.append(item)

        print(f"Filtered down to {len(filtered_items)} EW mode and LEVEL1 items for {netcdf_file}.")

        # Get the original ID from the dataset attributes
        original_id = ds.attrs.get('original_id', '')  # Adjust based on actual attribute name
        # Extract the part of original_id before '_icechart'
        original_id_prefix = original_id.split('_icechart')[0] if '_icechart' in original_id else original_id

        # Match the original_id with filtered items
        for filtered_item in filtered_items:
            filtered_id = filtered_item.id.split('.')[0]  # Remove the ".SAFE" part
            if original_id_prefix in filtered_id:  # Check for a match
                matching_items.append(filtered_item)
                break  # Stop after finding the first match

# Output the matched items
print(f"Total matching items collected: {len(matching_items)}")
for item in matching_items:
    print(item.id)
# Out:
# /mnt/raid_nvmeblue/r134p694/miniconda3/envs/cuda1/lib/python3.11/site-packages/pystac_client/item_search.py:888: FutureWarning: get_items() is deprecated, use items() instead
#   warnings.warn(
# Found 68 items matching bbox and datetime criteria for 20201229T104119_dmi_prep.nc.
# Filtered down to 42 EW mode and LEVEL1 items for 20201229T104119_dmi_prep.nc.
# Found 32 items matching bbox and datetime criteria for 20190831T144552_cis_prep.nc.
# Filtered down to 10 EW mode and LEVEL1 items for 20190831T144552_cis_prep.nc.
# Found 27 items matching bbox and datetime criteria for 20190612T101220_cis_prep.nc.
# Filtered down to 12 EW mode and LEVEL1 items for 20190612T101220_cis_prep.nc.
# Found 16 items matching bbox and datetime criteria for 20190411T102726_cis_prep.nc.
# Filtered down to 12 EW mode and LEVEL1 items for 20190411T102726_cis_prep.nc.
# Found 16 items matching bbox and datetime criteria for 20210509T104806_dmi_prep.nc.
# Filtered down to 6 EW mode and LEVEL1 items for 20210509T104806_dmi_prep.nc.
# Found 35 items matching bbox and datetime criteria for 20210728T120930_dmi_prep.nc.
# Filtered down to 15 EW mode and LEVEL1 items for 20210728T120930_dmi_prep.nc.
# Found 36 items matching bbox and datetime criteria for 20211105T193931_dmi_prep.nc.
# Filtered down to 10 EW mode and LEVEL1 items for 20211105T193931_dmi_prep.nc.
# Found 30 items matching bbox and datetime criteria for 20210625T194822_dmi_prep.nc.
# Filtered down to 10 EW mode and LEVEL1 items for 20210625T194822_dmi_prep.nc.
# Found 15 items matching bbox and datetime criteria for 20200203T104354_cis_prep.nc.
# Filtered down to 12 EW mode and LEVEL1 items for 20200203T104354_cis_prep.nc.
# Found 59 items matching bbox and datetime criteria for 20181202T185924_dmi_prep.nc.
# Filtered down to 34 EW mode and LEVEL1 items for 20181202T185924_dmi_prep.nc.
# Found 51 items matching bbox and datetime criteria for 20190619T185115_dmi_prep.nc.
# Filtered down to 30 EW mode and LEVEL1 items for 20190619T185115_dmi_prep.nc.
# Found 67 items matching bbox and datetime criteria for 20200412T110426_dmi_prep.nc.
# Filtered down to 48 EW mode and LEVEL1 items for 20200412T110426_dmi_prep.nc.
# Found 48 items matching bbox and datetime criteria for 20210715T211029_dmi_prep.nc.
# Filtered down to 17 EW mode and LEVEL1 items for 20210715T211029_dmi_prep.nc.
# Found 93 items matching bbox and datetime criteria for 20210203T104018_dmi_prep.nc.
# Filtered down to 64 EW mode and LEVEL1 items for 20210203T104018_dmi_prep.nc.
# Found 48 items matching bbox and datetime criteria for 20210504T104101_dmi_prep.nc.
# Filtered down to 22 EW mode and LEVEL1 items for 20210504T104101_dmi_prep.nc.
# Found 27 items matching bbox and datetime criteria for 20200424T102036_cis_prep.nc.
# Filtered down to 12 EW mode and LEVEL1 items for 20200424T102036_cis_prep.nc.
# Found 27 items matching bbox and datetime criteria for 20200319T102035_cis_prep.nc.
# Filtered down to 12 EW mode and LEVEL1 items for 20200319T102035_cis_prep.nc.
# Found 15 items matching bbox and datetime criteria for 20210523T121414_cis_prep.nc.
# Filtered down to 9 EW mode and LEVEL1 items for 20210523T121414_cis_prep.nc.
# Found 17 items matching bbox and datetime criteria for 20180621T214132_cis_prep.nc.
# Filtered down to 12 EW mode and LEVEL1 items for 20180621T214132_cis_prep.nc.
# Found 43 items matching bbox and datetime criteria for 20190721T210442_cis_prep.nc.
# Filtered down to 38 EW mode and LEVEL1 items for 20190721T210442_cis_prep.nc.
# Found 67 items matching bbox and datetime criteria for 20191231T205545_dmi_prep.nc.
# Filtered down to 58 EW mode and LEVEL1 items for 20191231T205545_dmi_prep.nc.
# Found 20 items matching bbox and datetime criteria for 20200517T214039_cis_prep.nc.
# Filtered down to 16 EW mode and LEVEL1 items for 20200517T214039_cis_prep.nc.
# Found 36 items matching bbox and datetime criteria for 20190129T205430_dmi_prep.nc.
# Filtered down to 25 EW mode and LEVEL1 items for 20190129T205430_dmi_prep.nc.
# Found 61 items matching bbox and datetime criteria for 20210503T104433_dmi_prep.nc.
# Filtered down to 24 EW mode and LEVEL1 items for 20210503T104433_dmi_prep.nc.
# Found 48 items matching bbox and datetime criteria for 20210621T211027_dmi_prep.nc.
# Filtered down to 17 EW mode and LEVEL1 items for 20210621T211027_dmi_prep.nc.
# Found 64 items matching bbox and datetime criteria for 20210620T212146_dmi_prep.nc.
# Filtered down to 38 EW mode and LEVEL1 items for 20210620T212146_dmi_prep.nc.
# Found 27 items matching bbox and datetime criteria for 20200208T114007_cis_prep.nc.
# Filtered down to 12 EW mode and LEVEL1 items for 20200208T114007_cis_prep.nc.
# Found 29 items matching bbox and datetime criteria for 20180902T124300_cis_prep.nc.
# Filtered down to 24 EW mode and LEVEL1 items for 20180902T124300_cis_prep.nc.
# Found 42 items matching bbox and datetime criteria for 20190519T194808_dmi_prep.nc.
# Filtered down to 20 EW mode and LEVEL1 items for 20190519T194808_dmi_prep.nc.
# Found 69 items matching bbox and datetime criteria for 20210927T075405_dmi_prep.nc.
# Filtered down to 23 EW mode and LEVEL1 items for 20210927T075405_dmi_prep.nc.
# Found 15 items matching bbox and datetime criteria for 20211225T121019_dmi_prep.nc.
# Filtered down to 9 EW mode and LEVEL1 items for 20211225T121019_dmi_prep.nc.
# Found 50 items matching bbox and datetime criteria for 20200825T211225_dmi_prep.nc.
# Filtered down to 44 EW mode and LEVEL1 items for 20200825T211225_dmi_prep.nc.
# Found 57 items matching bbox and datetime criteria for 20210707T082619_dmi_prep.nc.
# Filtered down to 27 EW mode and LEVEL1 items for 20210707T082619_dmi_prep.nc.
# Found 36 items matching bbox and datetime criteria for 20211124T193116_dmi_prep.nc.
# Filtered down to 10 EW mode and LEVEL1 items for 20211124T193116_dmi_prep.nc.
# Found 36 items matching bbox and datetime criteria for 20211216T082843_dmi_prep.nc.
# Filtered down to 18 EW mode and LEVEL1 items for 20211216T082843_dmi_prep.nc.
# Found 35 items matching bbox and datetime criteria for 20210614T212049_dmi_prep.nc.
# Filtered down to 9 EW mode and LEVEL1 items for 20210614T212049_dmi_prep.nc.
# Found 57 items matching bbox and datetime criteria for 20210121T082024_dmi_prep.nc.
# Filtered down to 44 EW mode and LEVEL1 items for 20210121T082024_dmi_prep.nc.
# Found 49 items matching bbox and datetime criteria for 20210217T214246_cis_prep.nc.
# Filtered down to 20 EW mode and LEVEL1 items for 20210217T214246_cis_prep.nc.
# Found 77 items matching bbox and datetime criteria for 20201211T211025_dmi_prep.nc.
# Filtered down to 42 EW mode and LEVEL1 items for 20201211T211025_dmi_prep.nc.
# Found 46 items matching bbox and datetime criteria for 20190522T210339_dmi_prep.nc.
# Filtered down to 40 EW mode and LEVEL1 items for 20190522T210339_dmi_prep.nc.
# Found 29 items matching bbox and datetime criteria for 20200728T214147_cis_prep.nc.
# Filtered down to 24 EW mode and LEVEL1 items for 20200728T214147_cis_prep.nc.
# Found 9 items matching bbox and datetime criteria for 20181108T114951_cis_prep.nc.
# Filtered down to 6 EW mode and LEVEL1 items for 20181108T114951_cis_prep.nc.
# Found 65 items matching bbox and datetime criteria for 20210214T212045_dmi_prep.nc.
# Filtered down to 36 EW mode and LEVEL1 items for 20210214T212045_dmi_prep.nc.
# Found 48 items matching bbox and datetime criteria for 20210812T123108_dmi_prep.nc.
# Filtered down to 24 EW mode and LEVEL1 items for 20210812T123108_dmi_prep.nc.
# Found 57 items matching bbox and datetime criteria for 20201016T082722_dmi_prep.nc.
# Filtered down to 45 EW mode and LEVEL1 items for 20201016T082722_dmi_prep.nc.
# Found 48 items matching bbox and datetime criteria for 20180929T081203_dmi_prep.nc.
# Filtered down to 36 EW mode and LEVEL1 items for 20180929T081203_dmi_prep.nc.
# Found 71 items matching bbox and datetime criteria for 20201013T080348_dmi_prep.nc.
# Filtered down to 52 EW mode and LEVEL1 items for 20201013T080348_dmi_prep.nc.
# Found 41 items matching bbox and datetime criteria for 20200624T212516_cis_prep.nc.
# Filtered down to 16 EW mode and LEVEL1 items for 20200624T212516_cis_prep.nc.
# Found 6 items matching bbox and datetime criteria for 20191103T114958_cis_prep.nc.
# Filtered down to 4 EW mode and LEVEL1 items for 20191103T114958_cis_prep.nc.
# Found 55 items matching bbox and datetime criteria for 20200110T104255_cis_prep.nc.
# Filtered down to 34 EW mode and LEVEL1 items for 20200110T104255_cis_prep.nc.
# Found 81 items matching bbox and datetime criteria for 20210124T214547_dmi_prep.nc.
# Filtered down to 70 EW mode and LEVEL1 items for 20210124T214547_dmi_prep.nc.
# Found 39 items matching bbox and datetime criteria for 20200514T104800_dmi_prep.nc.
# Filtered down to 28 EW mode and LEVEL1 items for 20200514T104800_dmi_prep.nc.
# Found 34 items matching bbox and datetime criteria for 20210806T194740_dmi_prep.nc.
# Filtered down to 10 EW mode and LEVEL1 items for 20210806T194740_dmi_prep.nc.
# Found 41 items matching bbox and datetime criteria for 20211215T074546_dmi_prep.nc.
# Filtered down to 14 EW mode and LEVEL1 items for 20211215T074546_dmi_prep.nc.
# Found 24 items matching bbox and datetime criteria for 20190826T152918_cis_prep.nc.
# Filtered down to 8 EW mode and LEVEL1 items for 20190826T152918_cis_prep.nc.
# Found 42 items matching bbox and datetime criteria for 20210706T115305_dmi_prep.nc.
# Filtered down to 15 EW mode and LEVEL1 items for 20210706T115305_dmi_prep.nc.
# Found 28 items matching bbox and datetime criteria for 20180919T125113_cis_prep.nc.
# Filtered down to 22 EW mode and LEVEL1 items for 20180919T125113_cis_prep.nc.
# Found 51 items matching bbox and datetime criteria for 20210308T074624_dmi_prep.nc.
# Filtered down to 18 EW mode and LEVEL1 items for 20210308T074624_dmi_prep.nc.
# Found 50 items matching bbox and datetime criteria for 20190129T205535_dmi_prep.nc.
# Filtered down to 44 EW mode and LEVEL1 items for 20190129T205535_dmi_prep.nc.
# Found 49 items matching bbox and datetime criteria for 20210531T074627_dmi_prep.nc.
# Filtered down to 18 EW mode and LEVEL1 items for 20210531T074627_dmi_prep.nc.
# Found 30 items matching bbox and datetime criteria for 20211110T082644_dmi_prep.nc.
# Filtered down to 15 EW mode and LEVEL1 items for 20211110T082644_dmi_prep.nc.
# Found 20 items matching bbox and datetime criteria for 20200610T214040_cis_prep.nc.
# Filtered down to 16 EW mode and LEVEL1 items for 20200610T214040_cis_prep.nc.
# Found 32 items matching bbox and datetime criteria for 20180829T131543_cis_prep.nc.
# Filtered down to 14 EW mode and LEVEL1 items for 20180829T131543_cis_prep.nc.
# Found 27 items matching bbox and datetime criteria for 20190119T101218_cis_prep.nc.
# Filtered down to 12 EW mode and LEVEL1 items for 20190119T101218_cis_prep.nc.
# Found 43 items matching bbox and datetime criteria for 20190615T210440_dmi_prep.nc.
# Filtered down to 38 EW mode and LEVEL1 items for 20190615T210440_dmi_prep.nc.
# Found 50 items matching bbox and datetime criteria for 20201112T080407_dmi_prep.nc.
# Filtered down to 32 EW mode and LEVEL1 items for 20201112T080407_dmi_prep.nc.
# Found 27 items matching bbox and datetime criteria for 20190112T102000_cis_prep.nc.
# Filtered down to 12 EW mode and LEVEL1 items for 20190112T102000_cis_prep.nc.
# Found 47 items matching bbox and datetime criteria for 20210415T081724_dmi_prep.nc.
# Filtered down to 25 EW mode and LEVEL1 items for 20210415T081724_dmi_prep.nc.
# Found 36 items matching bbox and datetime criteria for 20210520T082820_dmi_prep.nc.
# Filtered down to 18 EW mode and LEVEL1 items for 20210520T082820_dmi_prep.nc.
# Found 32 items matching bbox and datetime criteria for 20210629T075348_dmi_prep.nc.
# Filtered down to 12 EW mode and LEVEL1 items for 20210629T075348_dmi_prep.nc.
# Found 18 items matching bbox and datetime criteria for 20191016T155300_cis_prep.nc.
# Filtered down to 12 EW mode and LEVEL1 items for 20191016T155300_cis_prep.nc.
# Found 24 items matching bbox and datetime criteria for 20190524T101931_cis_prep.nc.
# Filtered down to 18 EW mode and LEVEL1 items for 20190524T101931_cis_prep.nc.
# Found 44 items matching bbox and datetime criteria for 20211025T081226_dmi_prep.nc.
# Filtered down to 22 EW mode and LEVEL1 items for 20211025T081226_dmi_prep.nc.
# Found 42 items matching bbox and datetime criteria for 20200805T194819_dmi_prep.nc.
# Filtered down to 20 EW mode and LEVEL1 items for 20200805T194819_dmi_prep.nc.
# Found 40 items matching bbox and datetime criteria for 20180327T103959_dmi_prep.nc.
# Filtered down to 22 EW mode and LEVEL1 items for 20180327T103959_dmi_prep.nc.
# Found 24 items matching bbox and datetime criteria for 20190401T101117_cis_prep.nc.
# Filtered down to 18 EW mode and LEVEL1 items for 20190401T101117_cis_prep.nc.
# Found 42 items matching bbox and datetime criteria for 20191115T082916_dmi_prep.nc.
# Filtered down to 32 EW mode and LEVEL1 items for 20191115T082916_dmi_prep.nc.
# Found 33 items matching bbox and datetime criteria for 20200619T122818_cis_prep.nc.
# Filtered down to 16 EW mode and LEVEL1 items for 20200619T122818_cis_prep.nc.
# Found 38 items matching bbox and datetime criteria for 20191020T205220_dmi_prep.nc.
# Filtered down to 30 EW mode and LEVEL1 items for 20191020T205220_dmi_prep.nc.
# Found 42 items matching bbox and datetime criteria for 20210814T211241_dmi_prep.nc.
# Filtered down to 24 EW mode and LEVEL1 items for 20210814T211241_dmi_prep.nc.
# Found 59 items matching bbox and datetime criteria for 20190807T121817_cis_prep.nc.
# Filtered down to 50 EW mode and LEVEL1 items for 20190807T121817_cis_prep.nc.
# Found 57 items matching bbox and datetime criteria for 20201115T105723_dmi_prep.nc.
# Filtered down to 34 EW mode and LEVEL1 items for 20201115T105723_dmi_prep.nc.
# Found 69 items matching bbox and datetime criteria for 20201112T112057_cis_prep.nc.
# Filtered down to 60 EW mode and LEVEL1 items for 20201112T112057_cis_prep.nc.
# Found 78 items matching bbox and datetime criteria for 20211101T085004_dmi_prep.nc.
# Filtered down to 41 EW mode and LEVEL1 items for 20211101T085004_dmi_prep.nc.
# Found 16 items matching bbox and datetime criteria for 20190525T203543_dmi_prep.nc.
# Filtered down to 12 EW mode and LEVEL1 items for 20190525T203543_dmi_prep.nc.
# Found 44 items matching bbox and datetime criteria for 20200213T203546_dmi_prep.nc.
# Filtered down to 12 EW mode and LEVEL1 items for 20200213T203546_dmi_prep.nc.
# Found 24 items matching bbox and datetime criteria for 20190831T130738_cis_prep.nc.
# Filtered down to 18 EW mode and LEVEL1 items for 20190831T130738_cis_prep.nc.
# Found 37 items matching bbox and datetime criteria for 20210116T210919_dmi_prep.nc.
# Filtered down to 28 EW mode and LEVEL1 items for 20210116T210919_dmi_prep.nc.
# Found 60 items matching bbox and datetime criteria for 20210814T211341_dmi_prep.nc.
# Filtered down to 35 EW mode and LEVEL1 items for 20210814T211341_dmi_prep.nc.
# Found 16 items matching bbox and datetime criteria for 20180922T113859_cis_prep.nc.
# Filtered down to 8 EW mode and LEVEL1 items for 20180922T113859_cis_prep.nc.
# Found 13 items matching bbox and datetime criteria for 20190831T144652_cis_prep.nc.
# Filtered down to 8 EW mode and LEVEL1 items for 20190831T144652_cis_prep.nc.
# Found 50 items matching bbox and datetime criteria for 20190527T211213_dmi_prep.nc.
# Filtered down to 44 EW mode and LEVEL1 items for 20190527T211213_dmi_prep.nc.
# Found 81 items matching bbox and datetime criteria for 20200924T211258_dmi_prep.nc.
# Filtered down to 70 EW mode and LEVEL1 items for 20200924T211258_dmi_prep.nc.
# Found 42 items matching bbox and datetime criteria for 20211206T081020_dmi_prep.nc.
# Filtered down to 21 EW mode and LEVEL1 items for 20211206T081020_dmi_prep.nc.
# Found 55 items matching bbox and datetime criteria for 20210921T120121_cis_prep.nc.
# Filtered down to 33 EW mode and LEVEL1 items for 20210921T120121_cis_prep.nc.
# Found 65 items matching bbox and datetime criteria for 20180826T093044_dmi_prep.nc.
# Filtered down to 38 EW mode and LEVEL1 items for 20180826T093044_dmi_prep.nc.
# Found 28 items matching bbox and datetime criteria for 20190206T212401_cis_prep.nc.
# Filtered down to 17 EW mode and LEVEL1 items for 20190206T212401_cis_prep.nc.
# Found 33 items matching bbox and datetime criteria for 20180424T194715_dmi_prep.nc.
# Filtered down to 11 EW mode and LEVEL1 items for 20180424T194715_dmi_prep.nc.
# Found 42 items matching bbox and datetime criteria for 20200714T184241_dmi_prep.nc.
# Filtered down to 26 EW mode and LEVEL1 items for 20200714T184241_dmi_prep.nc.
# Found 29 items matching bbox and datetime criteria for 20210920T210358_dmi_prep.nc.
# Filtered down to 17 EW mode and LEVEL1 items for 20210920T210358_dmi_prep.nc.
# Found 52 items matching bbox and datetime criteria for 20210116T193108_dmi_prep.nc.
# Filtered down to 14 EW mode and LEVEL1 items for 20210116T193108_dmi_prep.nc.
# Found 52 items matching bbox and datetime criteria for 20200918T081015_dmi_prep.nc.
# Filtered down to 41 EW mode and LEVEL1 items for 20200918T081015_dmi_prep.nc.
# Found 70 items matching bbox and datetime criteria for 20210118T075356_dmi_prep.nc.
# Filtered down to 39 EW mode and LEVEL1 items for 20210118T075356_dmi_prep.nc.
# Found 32 items matching bbox and datetime criteria for 20190812T131548_cis_prep.nc.
# Filtered down to 14 EW mode and LEVEL1 items for 20190812T131548_cis_prep.nc.
# Found 46 items matching bbox and datetime criteria for 20190603T210339_dmi_prep.nc.
# Filtered down to 40 EW mode and LEVEL1 items for 20190603T210339_dmi_prep.nc.
# Found 10 items matching bbox and datetime criteria for 20180903T155253_cis_prep.nc.
# Filtered down to 7 EW mode and LEVEL1 items for 20180903T155253_cis_prep.nc.
# Found 24 items matching bbox and datetime criteria for 20200807T153548_cis_prep.nc.
# Filtered down to 16 EW mode and LEVEL1 items for 20200807T153548_cis_prep.nc.
# Found 12 items matching bbox and datetime criteria for 20210309T105919_cis_prep.nc.
# Filtered down to 6 EW mode and LEVEL1 items for 20210309T105919_cis_prep.nc.
# Found 32 items matching bbox and datetime criteria for 20180325T194759_dmi_prep.nc.
# Filtered down to 10 EW mode and LEVEL1 items for 20180325T194759_dmi_prep.nc.
# Found 30 items matching bbox and datetime criteria for 20211122T082644_dmi_prep.nc.
# Filtered down to 15 EW mode and LEVEL1 items for 20211122T082644_dmi_prep.nc.
# Found 17 items matching bbox and datetime criteria for 20210521T082226_dmi_prep.nc.
# Filtered down to 6 EW mode and LEVEL1 items for 20210521T082226_dmi_prep.nc.
# Found 50 items matching bbox and datetime criteria for 20200925T080407_dmi_prep.nc.
# Filtered down to 32 EW mode and LEVEL1 items for 20200925T080407_dmi_prep.nc.
# Found 22 items matching bbox and datetime criteria for 20211220T102441_dmi_prep.nc.
# Filtered down to 12 EW mode and LEVEL1 items for 20211220T102441_dmi_prep.nc.
# Found 50 items matching bbox and datetime criteria for 20210607T082538_dmi_prep.nc.
# Filtered down to 21 EW mode and LEVEL1 items for 20210607T082538_dmi_prep.nc.
# Found 22 items matching bbox and datetime criteria for 20200920T160733_cis_prep.nc.
# Filtered down to 14 EW mode and LEVEL1 items for 20200920T160733_cis_prep.nc.
# Found 46 items matching bbox and datetime criteria for 20201203T082821_dmi_prep.nc.
# Filtered down to 32 EW mode and LEVEL1 items for 20201203T082821_dmi_prep.nc.
# Found 18 items matching bbox and datetime criteria for 20180923T201918_dmi_prep.nc.
# Filtered down to 13 EW mode and LEVEL1 items for 20180923T201918_dmi_prep.nc.
# Found 69 items matching bbox and datetime criteria for 20201217T211136_dmi_prep.nc.
# Filtered down to 42 EW mode and LEVEL1 items for 20201217T211136_dmi_prep.nc.
# Found 10 items matching bbox and datetime criteria for 20210530T102740_cis_prep.nc.
# Filtered down to 6 EW mode and LEVEL1 items for 20210530T102740_cis_prep.nc.
# Found 65 items matching bbox and datetime criteria for 20181022T180429_dmi_prep.nc.
# Filtered down to 37 EW mode and LEVEL1 items for 20181022T180429_dmi_prep.nc.
# Found 51 items matching bbox and datetime criteria for 20210205T214147_cis_prep.nc.
# Filtered down to 40 EW mode and LEVEL1 items for 20210205T214147_cis_prep.nc.
# Found 12 items matching bbox and datetime criteria for 20200919T161650_cis_prep.nc.
# Filtered down to 8 EW mode and LEVEL1 items for 20200919T161650_cis_prep.nc.
# Found 28 items matching bbox and datetime criteria for 20211015T205240_dmi_prep.nc.
# Filtered down to 4 EW mode and LEVEL1 items for 20211015T205240_dmi_prep.nc.
# Found 48 items matching bbox and datetime criteria for 20200312T102427_dmi_prep.nc.
# Filtered down to 40 EW mode and LEVEL1 items for 20200312T102427_dmi_prep.nc.
# Found 32 items matching bbox and datetime criteria for 20190924T144554_cis_prep.nc.
# Filtered down to 10 EW mode and LEVEL1 items for 20190924T144554_cis_prep.nc.
# Found 15 items matching bbox and datetime criteria for 20200415T104354_cis_prep.nc.
# Filtered down to 12 EW mode and LEVEL1 items for 20200415T104354_cis_prep.nc.
# Found 44 items matching bbox and datetime criteria for 20190216T205218_dmi_prep.nc.
# Filtered down to 12 EW mode and LEVEL1 items for 20190216T205218_dmi_prep.nc.
# Found 48 items matching bbox and datetime criteria for 20200326T203446_dmi_prep.nc.
# Filtered down to 16 EW mode and LEVEL1 items for 20200326T203446_dmi_prep.nc.
# Found 48 items matching bbox and datetime criteria for 20201204T211948_dmi_prep.nc.
# Filtered down to 36 EW mode and LEVEL1 items for 20201204T211948_dmi_prep.nc.
# Found 35 items matching bbox and datetime criteria for 20180421T080346_dmi_prep.nc.
# Filtered down to 18 EW mode and LEVEL1 items for 20180421T080346_dmi_prep.nc.
# Found 10 items matching bbox and datetime criteria for 20180821T165031_cis_prep.nc.
# Filtered down to 8 EW mode and LEVEL1 items for 20180821T165031_cis_prep.nc.
# Found 16 items matching bbox and datetime criteria for 20200124T102732_cis_prep.nc.
# Filtered down to 12 EW mode and LEVEL1 items for 20200124T102732_cis_prep.nc.
# Found 40 items matching bbox and datetime criteria for 20210116T193208_dmi_prep.nc.
# Filtered down to 8 EW mode and LEVEL1 items for 20210116T193208_dmi_prep.nc.
# Found 15 items matching bbox and datetime criteria for 20200807T122136_cis_prep.nc.
# Filtered down to 12 EW mode and LEVEL1 items for 20200807T122136_cis_prep.nc.
# Found 12 items matching bbox and datetime criteria for 20210407T101841_cis_prep.nc.
# Filtered down to 6 EW mode and LEVEL1 items for 20210407T101841_cis_prep.nc.
# Found 10 items matching bbox and datetime criteria for 20211222T105953_cis_prep.nc.
# Filtered down to 3 EW mode and LEVEL1 items for 20211222T105953_cis_prep.nc.
# Found 24 items matching bbox and datetime criteria for 20180427T103155_dmi_prep.nc.
# Filtered down to 17 EW mode and LEVEL1 items for 20180427T103155_dmi_prep.nc.
# Found 21 items matching bbox and datetime criteria for 20200921T164824_cis_prep.nc.
# Filtered down to 14 EW mode and LEVEL1 items for 20200921T164824_cis_prep.nc.
# Found 49 items matching bbox and datetime criteria for 20210429T080105_dmi_prep.nc.
# Filtered down to 26 EW mode and LEVEL1 items for 20210429T080105_dmi_prep.nc.
# Found 14 items matching bbox and datetime criteria for 20211014T210254_dmi_prep.nc.
# Filtered down to 8 EW mode and LEVEL1 items for 20211014T210254_dmi_prep.nc.
# Found 59 items matching bbox and datetime criteria for 20200628T205222_dmi_prep.nc.
# Filtered down to 30 EW mode and LEVEL1 items for 20200628T205222_dmi_prep.nc.
# Found 69 items matching bbox and datetime criteria for 20210912T212151_dmi_prep.nc.
# Filtered down to 26 EW mode and LEVEL1 items for 20210912T212151_dmi_prep.nc.
# Found 55 items matching bbox and datetime criteria for 20190511T120101_dmi_prep.nc.
# Filtered down to 46 EW mode and LEVEL1 items for 20190511T120101_dmi_prep.nc.
# Found 30 items matching bbox and datetime criteria for 20210113T101813_dmi_prep.nc.
# Filtered down to 18 EW mode and LEVEL1 items for 20210113T101813_dmi_prep.nc.
# Found 43 items matching bbox and datetime criteria for 20190807T104254_cis_prep.nc.
# Filtered down to 34 EW mode and LEVEL1 items for 20190807T104254_cis_prep.nc.
# Found 44 items matching bbox and datetime criteria for 20190306T102625_cis_prep.nc.
# Filtered down to 34 EW mode and LEVEL1 items for 20190306T102625_cis_prep.nc.
# Found 24 items matching bbox and datetime criteria for 20190612T101120_cis_prep.nc.
# Filtered down to 18 EW mode and LEVEL1 items for 20190612T101120_cis_prep.nc.
# Found 35 items matching bbox and datetime criteria for 20210628T192300_dmi_prep.nc.
# Filtered down to 10 EW mode and LEVEL1 items for 20210628T192300_dmi_prep.nc.
# Found 50 items matching bbox and datetime criteria for 20180924T080254_dmi_prep.nc.
# Filtered down to 39 EW mode and LEVEL1 items for 20180924T080254_dmi_prep.nc.
# Found 24 items matching bbox and datetime criteria for 20180812T130731_cis_prep.nc.
# Filtered down to 19 EW mode and LEVEL1 items for 20180812T130731_cis_prep.nc.
# Found 42 items matching bbox and datetime criteria for 20211007T081021_dmi_prep.nc.
# Filtered down to 21 EW mode and LEVEL1 items for 20211007T081021_dmi_prep.nc.
# Found 58 items matching bbox and datetime criteria for 20190730T123155_cis_prep.nc.
# Filtered down to 46 EW mode and LEVEL1 items for 20190730T123155_cis_prep.nc.
# Found 13 items matching bbox and datetime criteria for 20181028T123015_cis_prep.nc.
# Filtered down to 10 EW mode and LEVEL1 items for 20181028T123015_cis_prep.nc.
# Found 41 items matching bbox and datetime criteria for 20211014T080213_dmi_prep.nc.
# Filtered down to 21 EW mode and LEVEL1 items for 20211014T080213_dmi_prep.nc.
# Found 55 items matching bbox and datetime criteria for 20200201T212408_cis_prep.nc.
# Filtered down to 16 EW mode and LEVEL1 items for 20200201T212408_cis_prep.nc.
# Found 15 items matching bbox and datetime criteria for 20180821T151146_cis_prep.nc.
# Filtered down to 11 EW mode and LEVEL1 items for 20180821T151146_cis_prep.nc.
# Found 66 items matching bbox and datetime criteria for 20210709T085811_dmi_prep.nc.
# Filtered down to 35 EW mode and LEVEL1 items for 20210709T085811_dmi_prep.nc.
# Found 24 items matching bbox and datetime criteria for 20180829T113858_cis_prep.nc.
# Filtered down to 8 EW mode and LEVEL1 items for 20180829T113858_cis_prep.nc.
# Found 28 items matching bbox and datetime criteria for 20211029T203602_dmi_prep.nc.
# Filtered down to 4 EW mode and LEVEL1 items for 20211029T203602_dmi_prep.nc.
# Found 33 items matching bbox and datetime criteria for 20210520T082720_dmi_prep.nc.
# Filtered down to 17 EW mode and LEVEL1 items for 20210520T082720_dmi_prep.nc.
# Found 43 items matching bbox and datetime criteria for 20200703T210448_dmi_prep.nc.
# Filtered down to 38 EW mode and LEVEL1 items for 20200703T210448_dmi_prep.nc.
# Found 61 items matching bbox and datetime criteria for 20200930T080916_dmi_prep.nc.
# Filtered down to 49 EW mode and LEVEL1 items for 20200930T080916_dmi_prep.nc.
# Found 12 items matching bbox and datetime criteria for 20200930T201936_dmi_prep.nc.
# Filtered down to 8 EW mode and LEVEL1 items for 20200930T201936_dmi_prep.nc.
# Found 60 items matching bbox and datetime criteria for 20201230T080205_dmi_prep.nc.
# Filtered down to 29 EW mode and LEVEL1 items for 20201230T080205_dmi_prep.nc.
# Found 63 items matching bbox and datetime criteria for 20200728T120112_cis_prep.nc.
# Filtered down to 54 EW mode and LEVEL1 items for 20200728T120112_cis_prep.nc.
# Found 16 items matching bbox and datetime criteria for 20200523T102734_cis_prep.nc.
# Filtered down to 12 EW mode and LEVEL1 items for 20200523T102734_cis_prep.nc.
# Found 46 items matching bbox and datetime criteria for 20210426T114547_dmi_prep.nc.
# Filtered down to 27 EW mode and LEVEL1 items for 20210426T114547_dmi_prep.nc.
# Found 49 items matching bbox and datetime criteria for 20210624T074628_dmi_prep.nc.
# Filtered down to 18 EW mode and LEVEL1 items for 20210624T074628_dmi_prep.nc.
# Found 44 items matching bbox and datetime criteria for 20190505T102627_cis_prep.nc.
# Filtered down to 34 EW mode and LEVEL1 items for 20190505T102627_cis_prep.nc.
# Found 22 items matching bbox and datetime criteria for 20190731T131647_cis_prep.nc.
# Filtered down to 16 EW mode and LEVEL1 items for 20190731T131647_cis_prep.nc.
# Found 39 items matching bbox and datetime criteria for 20210519T115303_dmi_prep.nc.
# Filtered down to 15 EW mode and LEVEL1 items for 20210519T115303_dmi_prep.nc.
# Found 55 items matching bbox and datetime criteria for 20210720T211851_dmi_prep.nc.
# Filtered down to 12 EW mode and LEVEL1 items for 20210720T211851_dmi_prep.nc.
# Found 16 items matching bbox and datetime criteria for 20190908T205227_dmi_prep.nc.
# Filtered down to 12 EW mode and LEVEL1 items for 20190908T205227_dmi_prep.nc.
# Found 74 items matching bbox and datetime criteria for 20190304T112814_dmi_prep.nc.
# Filtered down to 65 EW mode and LEVEL1 items for 20190304T112814_dmi_prep.nc.
# Found 32 items matching bbox and datetime criteria for 20191014T205228_dmi_prep.nc.
# Filtered down to 8 EW mode and LEVEL1 items for 20191014T205228_dmi_prep.nc.
# Found 71 items matching bbox and datetime criteria for 20211025T085815_dmi_prep.nc.
# Filtered down to 37 EW mode and LEVEL1 items for 20211025T085815_dmi_prep.nc.
# Found 12 items matching bbox and datetime criteria for 20181118T120459_cis_prep.nc.
# Filtered down to 9 EW mode and LEVEL1 items for 20181118T120459_cis_prep.nc.
# Found 12 items matching bbox and datetime criteria for 20180410T214024_cis_prep.nc.
# Filtered down to 8 EW mode and LEVEL1 items for 20180410T214024_cis_prep.nc.
# Found 34 items matching bbox and datetime criteria for 20210809T112155_cis_prep.nc.
# Filtered down to 20 EW mode and LEVEL1 items for 20210809T112155_cis_prep.nc.
# Found 62 items matching bbox and datetime criteria for 20200928T114452_dmi_prep.nc.
# Filtered down to 54 EW mode and LEVEL1 items for 20200928T114452_dmi_prep.nc.
# Found 25 items matching bbox and datetime criteria for 20191013T210446_dmi_prep.nc.
# Filtered down to 20 EW mode and LEVEL1 items for 20191013T210446_dmi_prep.nc.
# Found 67 items matching bbox and datetime criteria for 20180820T120001_dmi_prep.nc.
# Filtered down to 56 EW mode and LEVEL1 items for 20180820T120001_dmi_prep.nc.
# Found 27 items matching bbox and datetime criteria for 20210113T110732_cis_prep.nc.
# Filtered down to 12 EW mode and LEVEL1 items for 20210113T110732_cis_prep.nc.
# Found 56 items matching bbox and datetime criteria for 20180914T115342_cis_prep.nc.
# Filtered down to 47 EW mode and LEVEL1 items for 20180914T115342_cis_prep.nc.
# Found 27 items matching bbox and datetime criteria for 20200224T102034_cis_prep.nc.
# Filtered down to 12 EW mode and LEVEL1 items for 20200224T102034_cis_prep.nc.
# Found 32 items matching bbox and datetime criteria for 20180721T120156_cis_prep.nc.
# Filtered down to 24 EW mode and LEVEL1 items for 20180721T120156_cis_prep.nc.
# Found 16 items matching bbox and datetime criteria for 20190105T102726_cis_prep.nc.
# Filtered down to 12 EW mode and LEVEL1 items for 20190105T102726_cis_prep.nc.
# Found 10 items matching bbox and datetime criteria for 20180810T155252_cis_prep.nc.
# Filtered down to 7 EW mode and LEVEL1 items for 20180810T155252_cis_prep.nc.
# Found 16 items matching bbox and datetime criteria for 20190306T102725_cis_prep.nc.
# Filtered down to 12 EW mode and LEVEL1 items for 20190306T102725_cis_prep.nc.
# Found 24 items matching bbox and datetime criteria for 20190507T101118_cis_prep.nc.
# Filtered down to 18 EW mode and LEVEL1 items for 20190507T101118_cis_prep.nc.
# Found 58 items matching bbox and datetime criteria for 20201026T070429_dmi_prep.nc.
# Filtered down to 37 EW mode and LEVEL1 items for 20201026T070429_dmi_prep.nc.
# Found 42 items matching bbox and datetime criteria for 20200910T194821_dmi_prep.nc.
# Filtered down to 20 EW mode and LEVEL1 items for 20200910T194821_dmi_prep.nc.
# Found 33 items matching bbox and datetime criteria for 20181028T114104_cis_prep.nc.
# Filtered down to 14 EW mode and LEVEL1 items for 20181028T114104_cis_prep.nc.
# Found 49 items matching bbox and datetime criteria for 20190808T120918_cis_prep.nc.
# Filtered down to 36 EW mode and LEVEL1 items for 20190808T120918_cis_prep.nc.
# Found 29 items matching bbox and datetime criteria for 20181029T201919_dmi_prep.nc.
# Filtered down to 20 EW mode and LEVEL1 items for 20181029T201919_dmi_prep.nc.
# Found 55 items matching bbox and datetime criteria for 20201007T210352_dmi_prep.nc.
# Filtered down to 48 EW mode and LEVEL1 items for 20201007T210352_dmi_prep.nc.
# Found 28 items matching bbox and datetime criteria for 20180607T184226_dmi_prep.nc.
# Filtered down to 15 EW mode and LEVEL1 items for 20180607T184226_dmi_prep.nc.
# Found 55 items matching bbox and datetime criteria for 20191212T210345_dmi_prep.nc.
# Filtered down to 48 EW mode and LEVEL1 items for 20191212T210345_dmi_prep.nc.
# Found 32 items matching bbox and datetime criteria for 20191012T081214_dmi_prep.nc.
# Filtered down to 20 EW mode and LEVEL1 items for 20191012T081214_dmi_prep.nc.
# Found 46 items matching bbox and datetime criteria for 20210824T114554_dmi_prep.nc.
# Filtered down to 27 EW mode and LEVEL1 items for 20210824T114554_dmi_prep.nc.
# Found 16 items matching bbox and datetime criteria for 20210528T113129_cis_prep.nc.
# Filtered down to 9 EW mode and LEVEL1 items for 20210528T113129_cis_prep.nc.
# Found 43 items matching bbox and datetime criteria for 20180222T101622_dmi_prep.nc.
# Filtered down to 18 EW mode and LEVEL1 items for 20180222T101622_dmi_prep.nc.
# Found 56 items matching bbox and datetime criteria for 20210919T211043_dmi_prep.nc.
# Filtered down to 8 EW mode and LEVEL1 items for 20210919T211043_dmi_prep.nc.
# Found 34 items matching bbox and datetime criteria for 20210615T211138_dmi_prep.nc.
# Filtered down to 11 EW mode and LEVEL1 items for 20210615T211138_dmi_prep.nc.
# Found 30 items matching bbox and datetime criteria for 20210611T120212_dmi_prep.nc.
# Filtered down to 18 EW mode and LEVEL1 items for 20210611T120212_dmi_prep.nc.
# Found 23 items matching bbox and datetime criteria for 20211130T211142_dmi_prep.nc.
# Filtered down to 13 EW mode and LEVEL1 items for 20211130T211142_dmi_prep.nc.
# Found 24 items matching bbox and datetime criteria for 20201012T130746_cis_prep.nc.
# Filtered down to 18 EW mode and LEVEL1 items for 20201012T130746_cis_prep.nc.
# Found 44 items matching bbox and datetime criteria for 20200312T102631_cis_prep.nc.
# Filtered down to 34 EW mode and LEVEL1 items for 20200312T102631_cis_prep.nc.
# Found 60 items matching bbox and datetime criteria for 20200124T102428_dmi_prep.nc.
# Filtered down to 36 EW mode and LEVEL1 items for 20200124T102428_dmi_prep.nc.
# Found 43 items matching bbox and datetime criteria for 20190607T082058_dmi_prep.nc.
# Filtered down to 32 EW mode and LEVEL1 items for 20190607T082058_dmi_prep.nc.
# Found 22 items matching bbox and datetime criteria for 20210522T201930_dmi_prep.nc.
# Filtered down to 6 EW mode and LEVEL1 items for 20210522T201930_dmi_prep.nc.
# Found 40 items matching bbox and datetime criteria for 20180808T075536_dmi_prep.nc.
# Filtered down to 17 EW mode and LEVEL1 items for 20180808T075536_dmi_prep.nc.
# Found 55 items matching bbox and datetime criteria for 20211108T120121_dmi_prep.nc.
# Filtered down to 33 EW mode and LEVEL1 items for 20211108T120121_dmi_prep.nc.
# Found 11 items matching bbox and datetime criteria for 20190709T121404_cis_prep.nc.
# Filtered down to 8 EW mode and LEVEL1 items for 20190709T121404_cis_prep.nc.
# Found 19 items matching bbox and datetime criteria for 20190317T103300_dmi_prep.nc.
# Filtered down to 16 EW mode and LEVEL1 items for 20190317T103300_dmi_prep.nc.
# Found 44 items matching bbox and datetime criteria for 20181009T181132_dmi_prep.nc.
# Filtered down to 35 EW mode and LEVEL1 items for 20181009T181132_dmi_prep.nc.
# Found 34 items matching bbox and datetime criteria for 20210609T211127_dmi_prep.nc.
# Filtered down to 19 EW mode and LEVEL1 items for 20210609T211127_dmi_prep.nc.
# Found 34 items matching bbox and datetime criteria for 20210919T153556_cis_prep.nc.
# Filtered down to 18 EW mode and LEVEL1 items for 20210919T153556_cis_prep.nc.
# Found 37 items matching bbox and datetime criteria for 20200904T082638_dmi_prep.nc.
# Filtered down to 29 EW mode and LEVEL1 items for 20200904T082638_dmi_prep.nc.
# Found 10 items matching bbox and datetime criteria for 20190117T111531_cis_prep.nc.
# Filtered down to 8 EW mode and LEVEL1 items for 20190117T111531_cis_prep.nc.
# Found 57 items matching bbox and datetime criteria for 20201210T212044_dmi_prep.nc.
# Filtered down to 38 EW mode and LEVEL1 items for 20201210T212044_dmi_prep.nc.
# Found 15 items matching bbox and datetime criteria for 20191013T152820_cis_prep.nc.
# Filtered down to 10 EW mode and LEVEL1 items for 20191013T152820_cis_prep.nc.
# Found 32 items matching bbox and datetime criteria for 20210726T202749_dmi_prep.nc.
# Filtered down to 6 EW mode and LEVEL1 items for 20210726T202749_dmi_prep.nc.
# Found 6 items matching bbox and datetime criteria for 20181104T122313_cis_prep.nc.
# Filtered down to 4 EW mode and LEVEL1 items for 20181104T122313_cis_prep.nc.
# Found 78 items matching bbox and datetime criteria for 20210127T212142_dmi_prep.nc.
# Filtered down to 42 EW mode and LEVEL1 items for 20210127T212142_dmi_prep.nc.
# Found 60 items matching bbox and datetime criteria for 20211013T211343_dmi_prep.nc.
# Filtered down to 35 EW mode and LEVEL1 items for 20211013T211343_dmi_prep.nc.
# Found 24 items matching bbox and datetime criteria for 20190430T101830_cis_prep.nc.
# Filtered down to 18 EW mode and LEVEL1 items for 20190430T101830_cis_prep.nc.
# Found 43 items matching bbox and datetime criteria for 20190330T102526_dmi_prep.nc.
# Filtered down to 34 EW mode and LEVEL1 items for 20190330T102526_dmi_prep.nc.
# Found 45 items matching bbox and datetime criteria for 20201221T082637_dmi_prep.nc.
# Filtered down to 29 EW mode and LEVEL1 items for 20201221T082637_dmi_prep.nc.
# Found 32 items matching bbox and datetime criteria for 20190924T121820_cis_prep.nc.
# Filtered down to 26 EW mode and LEVEL1 items for 20190924T121820_cis_prep.nc.
# Found 57 items matching bbox and datetime criteria for 20210318T080139_dmi_prep.nc.
# Filtered down to 28 EW mode and LEVEL1 items for 20210318T080139_dmi_prep.nc.
# Found 32 items matching bbox and datetime criteria for 20210415T211945_dmi_prep.nc.
# Filtered down to 15 EW mode and LEVEL1 items for 20210415T211945_dmi_prep.nc.
# Found 44 items matching bbox and datetime criteria for 20200928T203556_dmi_prep.nc.
# Filtered down to 12 EW mode and LEVEL1 items for 20200928T203556_dmi_prep.nc.
# Found 33 items matching bbox and datetime criteria for 20210905T203605_dmi_prep.nc.
# Filtered down to 6 EW mode and LEVEL1 items for 20210905T203605_dmi_prep.nc.
# Found 21 items matching bbox and datetime criteria for 20191006T153634_cis_prep.nc.
# Filtered down to 14 EW mode and LEVEL1 items for 20191006T153634_cis_prep.nc.
# Found 70 items matching bbox and datetime criteria for 20210112T084156_dmi_prep.nc.
# Filtered down to 42 EW mode and LEVEL1 items for 20210112T084156_dmi_prep.nc.
# Found 80 items matching bbox and datetime criteria for 20200227T104053_dmi_prep.nc.
# Filtered down to 58 EW mode and LEVEL1 items for 20200227T104053_dmi_prep.nc.
# Found 34 items matching bbox and datetime criteria for 20180122T205424_dmi_prep.nc.
# Filtered down to 16 EW mode and LEVEL1 items for 20180122T205424_dmi_prep.nc.
# Found 65 items matching bbox and datetime criteria for 20200831T081119_dmi_prep.nc.
# Filtered down to 50 EW mode and LEVEL1 items for 20200831T081119_dmi_prep.nc.
# Found 21 items matching bbox and datetime criteria for 20210701T082640_dmi_prep.nc.
# Filtered down to 11 EW mode and LEVEL1 items for 20210701T082640_dmi_prep.nc.
# Found 14 items matching bbox and datetime criteria for 20210722T210250_dmi_prep.nc.
# Filtered down to 8 EW mode and LEVEL1 items for 20210722T210250_dmi_prep.nc.
# Found 43 items matching bbox and datetime criteria for 20191106T210446_dmi_prep.nc.
# Filtered down to 38 EW mode and LEVEL1 items for 20191106T210446_dmi_prep.nc.
# Found 11 items matching bbox and datetime criteria for 20180903T155353_cis_prep.nc.
# Filtered down to 5 EW mode and LEVEL1 items for 20180903T155353_cis_prep.nc.
# Found 50 items matching bbox and datetime criteria for 20200628T205622_dmi_prep.nc.
# Filtered down to 44 EW mode and LEVEL1 items for 20200628T205622_dmi_prep.nc.
# Found 15 items matching bbox and datetime criteria for 20210714T114034_cis_prep.nc.
# Filtered down to 9 EW mode and LEVEL1 items for 20210714T114034_cis_prep.nc.
# Found 27 items matching bbox and datetime criteria for 20200131T101805_cis_prep.nc.
# Filtered down to 18 EW mode and LEVEL1 items for 20200131T101805_cis_prep.nc.
# Found 22 items matching bbox and datetime criteria for 20210421T082208_dmi_prep.nc.
# Filtered down to 6 EW mode and LEVEL1 items for 20210421T082208_dmi_prep.nc.
# Found 24 items matching bbox and datetime criteria for 20200830T113911_cis_prep.nc.
# Filtered down to 8 EW mode and LEVEL1 items for 20200830T113911_cis_prep.nc.
# Found 53 items matching bbox and datetime criteria for 20190930T121732_cis_prep.nc.
# Filtered down to 44 EW mode and LEVEL1 items for 20190930T121732_cis_prep.nc.
# Found 53 items matching bbox and datetime criteria for 20181211T103202_dmi_prep.nc.
# Filtered down to 44 EW mode and LEVEL1 items for 20181211T103202_dmi_prep.nc.
# Found 12 items matching bbox and datetime criteria for 20190922T155400_cis_prep.nc.
# Filtered down to 6 EW mode and LEVEL1 items for 20190922T155400_cis_prep.nc.
# Found 49 items matching bbox and datetime criteria for 20201209T082938_dmi_prep.nc.
# Filtered down to 24 EW mode and LEVEL1 items for 20201209T082938_dmi_prep.nc.
# Found 22 items matching bbox and datetime criteria for 20200506T102036_cis_prep.nc.
# Filtered down to 12 EW mode and LEVEL1 items for 20200506T102036_cis_prep.nc.
# Found 30 items matching bbox and datetime criteria for 20210414T194818_dmi_prep.nc.
# Filtered down to 10 EW mode and LEVEL1 items for 20210414T194818_dmi_prep.nc.
# Found 39 items matching bbox and datetime criteria for 20210624T074828_dmi_prep.nc.
# Filtered down to 20 EW mode and LEVEL1 items for 20210624T074828_dmi_prep.nc.
# Found 33 items matching bbox and datetime criteria for 20200423T214037_cis_prep.nc.
# Filtered down to 16 EW mode and LEVEL1 items for 20200423T214037_cis_prep.nc.
# Found 39 items matching bbox and datetime criteria for 20180108T184332_dmi_prep.nc.
# Filtered down to 20 EW mode and LEVEL1 items for 20180108T184332_dmi_prep.nc.
# Found 53 items matching bbox and datetime criteria for 20210127T211842_dmi_prep.nc.
# Filtered down to 18 EW mode and LEVEL1 items for 20210127T211842_dmi_prep.nc.
# Found 33 items matching bbox and datetime criteria for 20210402T203557_dmi_prep.nc.
# Filtered down to 6 EW mode and LEVEL1 items for 20210402T203557_dmi_prep.nc.
# Found 21 items matching bbox and datetime criteria for 20181028T114204_cis_prep.nc.
# Filtered down to 13 EW mode and LEVEL1 items for 20181028T114204_cis_prep.nc.
# Found 44 items matching bbox and datetime criteria for 20200706T203552_dmi_prep.nc.
# Filtered down to 12 EW mode and LEVEL1 items for 20200706T203552_dmi_prep.nc.
# Found 23 items matching bbox and datetime criteria for 20210527T211945_dmi_prep.nc.
# Filtered down to 11 EW mode and LEVEL1 items for 20210527T211945_dmi_prep.nc.
# Found 52 items matching bbox and datetime criteria for 20190607T202733_dmi_prep.nc.
# Filtered down to 20 EW mode and LEVEL1 items for 20190607T202733_dmi_prep.nc.
# Found 74 items matching bbox and datetime criteria for 20210202T211845_dmi_prep.nc.
# Filtered down to 30 EW mode and LEVEL1 items for 20210202T211845_dmi_prep.nc.
# Found 62 items matching bbox and datetime criteria for 20210202T211745_dmi_prep.nc.
# Filtered down to 24 EW mode and LEVEL1 items for 20210202T211745_dmi_prep.nc.
# Found 97 items matching bbox and datetime criteria for 20210203T211334_dmi_prep.nc.
# Filtered down to 84 EW mode and LEVEL1 items for 20210203T211334_dmi_prep.nc.
# Found 75 items matching bbox and datetime criteria for 20211214T115920_dmi_prep.nc.
# Filtered down to 36 EW mode and LEVEL1 items for 20211214T115920_dmi_prep.nc.
# Found 59 items matching bbox and datetime criteria for 20210128T103956_dmi_prep.nc.
# Filtered down to 52 EW mode and LEVEL1 items for 20210128T103956_dmi_prep.nc.
# Found 32 items matching bbox and datetime criteria for 20190917T131550_cis_prep.nc.
# Filtered down to 14 EW mode and LEVEL1 items for 20190917T131550_cis_prep.nc.
# Found 38 items matching bbox and datetime criteria for 20191028T132259_cis_prep.nc.
# Filtered down to 20 EW mode and LEVEL1 items for 20191028T132259_cis_prep.nc.
# Found 21 items matching bbox and datetime criteria for 20190819T153633_cis_prep.nc.
# Filtered down to 14 EW mode and LEVEL1 items for 20190819T153633_cis_prep.nc.
# Found 80 items matching bbox and datetime criteria for 20201215T082616_dmi_prep.nc.
# Filtered down to 49 EW mode and LEVEL1 items for 20201215T082616_dmi_prep.nc.
# Found 11 items matching bbox and datetime criteria for 20180619T104303_cis_prep.nc.
# Filtered down to 8 EW mode and LEVEL1 items for 20180619T104303_cis_prep.nc.
# Found 47 items matching bbox and datetime criteria for 20210906T081732_dmi_prep.nc.
# Filtered down to 25 EW mode and LEVEL1 items for 20210906T081732_dmi_prep.nc.
# Found 22 items matching bbox and datetime criteria for 20211126T102442_dmi_prep.nc.
# Filtered down to 12 EW mode and LEVEL1 items for 20211126T102442_dmi_prep.nc.
# Found 62 items matching bbox and datetime criteria for 20190117T102422_dmi_prep.nc.
# Filtered down to 37 EW mode and LEVEL1 items for 20190117T102422_dmi_prep.nc.
# Found 55 items matching bbox and datetime criteria for 20210418T214547_dmi_prep.nc.
# Filtered down to 33 EW mode and LEVEL1 items for 20210418T214547_dmi_prep.nc.
# Found 14 items matching bbox and datetime criteria for 20210417T210245_dmi_prep.nc.
# Filtered down to 8 EW mode and LEVEL1 items for 20210417T210245_dmi_prep.nc.
# Found 21 items matching bbox and datetime criteria for 20210331T205323_dmi_prep.nc.
# Filtered down to 8 EW mode and LEVEL1 items for 20210331T205323_dmi_prep.nc.
# Found 42 items matching bbox and datetime criteria for 20200726T184242_dmi_prep.nc.
# Filtered down to 28 EW mode and LEVEL1 items for 20200726T184242_dmi_prep.nc.
# Found 30 items matching bbox and datetime criteria for 20211023T194827_dmi_prep.nc.
# Filtered down to 10 EW mode and LEVEL1 items for 20211023T194827_dmi_prep.nc.
# Found 24 items matching bbox and datetime criteria for 20200922T172924_cis_prep.nc.
# Filtered down to 16 EW mode and LEVEL1 items for 20200922T172924_cis_prep.nc.
# Found 68 items matching bbox and datetime criteria for 20180907T120159_cis_prep.nc.
# Filtered down to 57 EW mode and LEVEL1 items for 20180907T120159_cis_prep.nc.
# Found 22 items matching bbox and datetime criteria for 20190824T131649_cis_prep.nc.
# Filtered down to 16 EW mode and LEVEL1 items for 20190824T131649_cis_prep.nc.
# Found 44 items matching bbox and datetime criteria for 20200223T205225_dmi_prep.nc.
# Filtered down to 12 EW mode and LEVEL1 items for 20200223T205225_dmi_prep.nc.
# Found 21 items matching bbox and datetime criteria for 20190929T140604_cis_prep.nc.
# Filtered down to 14 EW mode and LEVEL1 items for 20190929T140604_cis_prep.nc.
# Found 11 items matching bbox and datetime criteria for 20180929T130833_cis_prep.nc.
# Filtered down to 8 EW mode and LEVEL1 items for 20180929T130833_cis_prep.nc.
# Found 51 items matching bbox and datetime criteria for 20190802T183536_dmi_prep.nc.
# Filtered down to 32 EW mode and LEVEL1 items for 20190802T183536_dmi_prep.nc.
# Found 22 items matching bbox and datetime criteria for 20190929T140504_cis_prep.nc.
# Filtered down to 14 EW mode and LEVEL1 items for 20190929T140504_cis_prep.nc.
# Found 25 items matching bbox and datetime criteria for 20190826T152818_cis_prep.nc.
# Filtered down to 14 EW mode and LEVEL1 items for 20190826T152818_cis_prep.nc.
# Found 42 items matching bbox and datetime criteria for 20210901T081020_dmi_prep.nc.
# Filtered down to 21 EW mode and LEVEL1 items for 20210901T081020_dmi_prep.nc.
# Found 72 items matching bbox and datetime criteria for 20190501T212607_cis_prep.nc.
# Filtered down to 36 EW mode and LEVEL1 items for 20190501T212607_cis_prep.nc.
# Found 40 items matching bbox and datetime criteria for 20210825T180347_dmi_prep.nc.
# Filtered down to 16 EW mode and LEVEL1 items for 20210825T180347_dmi_prep.nc.
# Found 36 items matching bbox and datetime criteria for 20210831T202810_dmi_prep.nc.
# Filtered down to 6 EW mode and LEVEL1 items for 20210831T202810_dmi_prep.nc.
# Found 62 items matching bbox and datetime criteria for 20190809T214629_cis_prep.nc.
# Filtered down to 54 EW mode and LEVEL1 items for 20190809T214629_cis_prep.nc.
# ...
# S1B_EW_GRDM_1SDH_20210831T202810_20210831T202910_028495_03667D_EFEC.SAFE
# S1A_EW_GRDM_1SDH_20190809T214629_20190809T214705_028498_0338AE_EDB1.SAFE
# S1B_EW_GRDM_1SDH_20210614T081827_20210614T081927_027350_034434_DDD3.SAFE
# S1B_EW_GRDM_1SDH_20210203T104118_20210203T104133_025441_0307CD_1850.SAFE
# S1B_EW_GRDM_1SDH_20190704T205616_20190704T205716_016989_01FF72_F6F5.SAFE
# S1A_EW_GRDM_1SDH_20200505T205226_20200505T205331_032435_03C198_05FD.SAFE
# S1B_EW_GRDM_1SDH_20191213T120108_20191213T120208_019346_02489D_EC20.SAFE
# S1A_EW_GRDM_1SDH_20190904T132454_20190904T132553_028872_0345B6_9BDD.SAFE
# S1B_EW_GRDM_1SDH_20210528T210921_20210528T211026_027110_033D0B_AA66.SAFE
# S1A_EW_GRDM_1SDH_20190304T104047_20190304T104147_026187_02EC71_995E.SAFE
# S1B_EW_GRDM_1SDH_20211114T205332_20211114T205432_029589_0387FC_8D3B.SAFE
# S1A_EW_GRDM_1SDH_20210321T194818_20210321T194918_037101_045E27_42D5.SAFE
# S1B_EW_GRDM_1SDH_20191008T125119_20191008T125219_018384_022A1A_8F16.SAFE
# S1B_EW_GRDM_1SDH_20180824T130831_20180824T130925_012405_016DF4_67D8.SAFE
# S1A_EW_GRDM_1SDH_20201119T120712_20201119T120801_035317_042027_5831.SAFE
# S1B_EW_GRDM_1SDH_20200620T104216_20200620T104259_022116_029F8D_8890.SAFE
# S1B_EW_GRDM_1SDH_20190115T112815_20190115T112915_014504_01B040_9044.SAFE
# S1A_EW_GRDM_1SDH_20210411T174833_20210411T174936_037406_04689E_AC18.SAFE
# S1A_EW_GRDM_1SDH_20181111T121402_20181111T121502_024540_02B161_E54F.SAFE
# S1A_EW_GRDM_1SDH_20190912T184444_20190912T184549_028992_0349DD_0C66.SAFE
# S1B_EW_GRDM_1SDH_20210901T211231_20210901T211250_028510_0366F1_8582.SAFE
# S1B_EW_GRDM_1SDH_20190707T212001_20190707T212101_017033_0200B5_67A8.SAFE
# S1B_EW_GRDM_1SDH_20201007T210248_20201007T210352_023712_02D0F2_CCB9.SAFE
# S1A_EW_GRDM_1SDH_20190809T120404_20190809T120504_028492_03387D_1969.SAFE
# S1A_EW_GRDM_1SDH_20200809T205232_20200809T205336_033835_03EC5F_50FC.SAFE
# S1A_EW_GRDM_1SDH_20200424T101936_20200424T102036_032268_03BBA9_1CA8.SAFE
# S1A_EW_GRDM_1SDH_20190813T081112_20190813T081212_028548_033A7B_62C9.SAFE
# S1B_EW_GRDM_1SDH_20201117T193110_20201117T193210_024309_02E389_AF20.SAFE
# S1B_EW_GRDM_1SDH_20211002T210358_20211002T210458_028962_0374C8_A655.SAFE
# S1B_EW_GRDM_1SDH_20181102T212609_20181102T212657_013431_018D9D_90C9.SAFE
# S1B_EW_GRDM_1SDH_20201211T210921_20201211T211025_024660_02EEBE_3A2D.SAFE
# S1B_EW_GRDM_1SDH_20211119T080313_20211119T080413_029654_0389FB_9317.SAFE
# S1B_EW_GRDM_1SDH_20180922T145543_20180922T145626_012829_017AFC_5728.SAFE
# S1B_EW_GRDM_1SDH_20180926T124301_20180926T124401_012886_017CBE_D62E.SAFE
# S1A_EW_GRDM_1SDH_20210828T205443_20210828T205544_039435_04A8A3_756F.SAFE
# S1A_EW_GRDM_1SDH_20200927T165045_20200927T165146_034547_040561_1061.SAFE
# S1A_EW_GRDM_1SDH_20200831T211357_20200831T211510_034156_03F7AD_3998.SAFE

# %%
from oauthlib.oauth2 import BackendApplicationClient
from requests_oauthlib import OAuth2Session

# Your client credentials
client_id = '###'
client_secret = '###'

# Create a session
client = BackendApplicationClient(client_id=client_id)
oauth = OAuth2Session(client=client)

# Get token for the session
token = oauth.fetch_token(token_url='https://identity.dataspace.copernicus.eu/auth/realms/CDSE/protocol/openid-connect/token',
                          client_secret=client_secret, include_client_id=True)

def sentinelhub_compliance_hook(response):
    response.raise_for_status()
    return response

oauth.register_compliance_hook("access_token_response", sentinelhub_compliance_hook)
# All requests using this session will have an access token automatically added
resp = oauth.get("https://sh.dataspace.copernicus.eu/configuration/v1/wms/instances")
print(resp.content)
# Out:
# b'[]'

# %%
import requests
def get_keycloak(username: str, password: str) -> str:
    data = {
        "client_id": "cdse-public",
        "username": username,
        "password": password,
        "grant_type": "password",
    }
    try:
        r = requests.post(
            "https://identity.dataspace.copernicus.eu/auth/realms/CDSE/protocol/openid-connect/token",
            data=data,
        )
        r.raise_for_status()
    except Exception as e:
        raise Exception(
            f"Keycloak token creation failed. Reponse from the server was: {r.json()}"
        )
    return r.json()["access_token"]

keycloak_token = get_keycloak('###','###')
keycloak_token
# Out:
# 'eyJhbGciOiJSUzI1NiIsInR5cCIgOiAiSldUIiwia2lkIiA6ICJYVUh3VWZKaHVDVWo0X3k4ZF8xM0hxWXBYMFdwdDd2anhob2FPLUxzREZFIn0.....AiutEVPXuhwzW4_PyFyeu43mwtAw65knd73LjXIwGq23gJbksSCHCOX-ASbcaPz3mzvh4_gP9VV4zfM3DhOafCUvLmcyHbroOXgLrz4Jm1PV6jbtkVrLwunSc7Dyjb0p_fJiUlH5WLv-xBVQQl44wTD3kZ0TfYD1tx3vT2utBFVV4TF7hBLxkSOyrsV5c7m_8-B9Hpp_-KlEEfka_dBBl4AvJz7pNkVXku5-RN5fVYTNFixbozjz1e-looJx8-SjAyI3k9cIUrBvvBURT6VBahNAFR3Uvhejai_P_FWaZdXRPiyAG4sjg-gaDWtsxOmDlawqUWJxEBuWi7XOdxvL3w'

# %% [markdown]
# ## Get Safe Products

# %%
import os
import requests
import time
from datetime import datetime, timedelta

# Ensure the directory exists
output_dir = 'ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/'
os.makedirs(output_dir, exist_ok=True)

# Global variables to store the token and its expiration time
keycloak_token = None
token_expiration_time = None

def get_keycloak(username: str, password: str) -> str:
    global keycloak_token, token_expiration_time
    
    # If the token exists and hasn't expired, return it
    if keycloak_token and token_expiration_time > datetime.utcnow():
        return keycloak_token
    
    # Otherwise, request a new token
    data = {
        "client_id": "cdse-public",
        "username": username,
        "password": password,
        "grant_type": "password",
    }
    try:
        r = requests.post(
            "https://identity.dataspace.copernicus.eu/auth/realms/CDSE/protocol/openid-connect/token",
            data=data,
        )
        r.raise_for_status()
    except Exception as e:
        raise Exception(f"Keycloak token creation failed. Response from the server was: {r.json()}")
    
    # Extract the access token and expiration time (in seconds)
    token_data = r.json()
    keycloak_token = token_data["access_token"]
    expires_in = token_data.get("expires_in", 600)  # Default to 600 if not provided
    
    # Calculate the expiration time
    token_expiration_time = datetime.utcnow() + timedelta(seconds=expires_in)
    
    print(f"Token will expire at: {token_expiration_time}")
    
    return keycloak_token

# Function to download the item
def download_item(item):
    # Get the valid Keycloak token
    token = get_keycloak('###', '###')
    
    # Access the 'PRODUCT' asset to get the download link
    product_asset = item.assets.get('PRODUCT')
    
    if product_asset:
        # Extract the product ID from the asset URL
        product_id = product_asset.href.split('(')[1].split(')')[0]  # Extract the product ID
        
        # Construct the download URL for the ZIP file
        download_url = f'https://zipper.dataspace.copernicus.eu/odata/v1/Products({product_id})/$value'

        print(f"Downloading from: {download_url}")
        
        # Optional: Use headers for authorization if needed
        headers = {
            'Authorization': f"Bearer {token}"  # Use the valid token here
        }
        
        # Download the file
        response = requests.get(download_url, headers=headers)
        
        if response.status_code == 200:
            # Save the file as a ZIP
            file_name = os.path.join(output_dir, f"{item.id}.zip")  # Change the extension to .zip
            with open(file_name, 'wb') as f:
                f.write(response.content)
            print(f"Downloaded: {file_name}")
        else:
            print(f"Failed to download {item.id} with status code: {response.status_code}")
            print(f"Error Message: {response.text if response.text else 'No additional error message'}")
    else:
        print(f"No PRODUCT asset found for {item.id}")

# Iterate through filtered items and download each
for item in matching_items:
    download_item(item)
# Out:
# Token will expire at: 2024-11-13 22:45:34.152218
# Downloading from: https://zipper.dataspace.copernicus.eu/odata/v1/Products(ce0bc2f4-700c-50e4-92b7-9a625df89912)/$value
# Downloaded: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/S1B_EW_GRDM_1SDH_20201229T104119_20201229T104219_024916_02F703_C262.SAFE.zip
# Downloading from: https://zipper.dataspace.copernicus.eu/odata/v1/Products(94ea1e1c-61c5-54fe-8898-e5c783faac10)/$value
# Downloaded: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/S1B_EW_GRDM_1SDH_20190831T144552_20190831T144652_017831_0218EB_1D2C.SAFE.zip
# Downloading from: https://zipper.dataspace.copernicus.eu/odata/v1/Products(ee58b06a-614a-5fd5-837f-de768fff7545)/$value
# Downloaded: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/S1A_EW_GRDM_1SDH_20190612T101220_20190612T101253_027645_031ECD_9713.SAFE.zip
# Downloading from: https://zipper.dataspace.copernicus.eu/odata/v1/Products(4d6d0585-78b4-52a0-98d3-3ca23c4d12ce)/$value
# Downloaded: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/S1A_EW_GRDM_1SDH_20190411T102726_20190411T102827_026741_0300CC_648B.SAFE.zip
# Downloading from: https://zipper.dataspace.copernicus.eu/odata/v1/Products(e132dd58-54af-5075-ba5b-b290a6ffeaa7)/$value
# Downloaded: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/S1A_EW_GRDM_1SDH_20210509T104806_20210509T104910_037810_04766D_13A0.SAFE.zip
# Downloading from: https://zipper.dataspace.copernicus.eu/odata/v1/Products(704bc779-82b4-586f-aff1-50fa21f8ebc2)/$value
# Downloaded: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/S1B_EW_GRDM_1SDH_20
dir = r'ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/'
netcdf_dir = r'ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/netcdfs/'

# Ensure the NetCDF directory exists
os.makedirs(netcdf_dir, exist_ok=True)

# Function to read TIFF data directly from bytes and add it as a DataArray
def read_tiff_from_bytes(tiff_bytes, variable_name):
    print(f"Reading {variable_name} TIFF data into memory...")
    with rasterio.open(BytesIO(tiff_bytes)) as src:
        data = src.read(1)  # Read the first band
        coords = {
            'y': np.arange(data.shape[0]),
            'x': np.arange(data.shape[1])
        }
        da = xr.DataArray(data, dims=['y', 'x'], coords=coords, name=variable_name)
    print(f"Finished reading {variable_name} data.")
    return da

# Counter for processed files
total_files = len([f for f in os.listdir(source_dir) if f.endswith('.zip')])
processed_files = 0

print(f"Found {total_files} ZIP files to process.")

# Loop through all ZIP files
for file_name in os.listdir(source_dir):
    if file_name.endswith('.zip'):
        zip_path = os.path.join(source_dir, file_name)
        base_name = os.path.splitext(file_name)[0]  # Name without extension

        # Create NetCDF file for each ZIP file
        netcdf_path = os.path.join(netcdf_dir, f"{base_name}.nc")
        datasets = []

        print(f"\nProcessing ZIP file: {file_name}")

        with zipfile.ZipFile(zip_path, 'r') as zip_ref:
            hh_data = None
            hv_data = None

            # Track the number of TIFF files processed in this ZIP
            tiff_count = 0

            for zip_info in zip_ref.infolist():
                # Only process files in the "measurement" folder
                if 'measurement' in zip_info.filename and zip_info.filename.endswith('.tiff'):
                    print(f"Found TIFF file: {zip_info.filename}")
                    tiff_bytes = zip_ref.read(zip_info.filename)
                    tiff_count += 1

                    # Check if the file name contains "hh" or "hv"
                    if 'hh' in zip_info.filename.lower():
                        hh_data = read_tiff_from_bytes(tiff_bytes, 'hh')
                    elif 'hv' in zip_info.filename.lower():
                        hv_data = read_tiff_from_bytes(tiff_bytes, 'hv')

            print(f"Processed {tiff_count} TIFF files from {file_name}.")

            # Combine HH and HV data into a single xarray Dataset
            if hh_data is not None and hv_data is not None:
                ds = xr.Dataset({'hh': hh_data, 'hv': hv_data})
                datasets.append(ds)
                print(f"Created xarray Dataset for {file_name}.")

        # Write the combined dataset to NetCDF
        if datasets:
            combined_ds = xr.combine_by_coords(datasets)
            combined_ds.to_netcdf(netcdf_path)
            print(f"Saved NetCDF: {netcdf_path}")

        # Increment processed file count and print progress
        processed_files += 1
        print(f"Completed {processed_files}/{total_files} ZIP files.")

print("All TIFF files have been saved in NetCDF files!")
# Out:
# Found 510 ZIP files to process.
#
# Processing ZIP file: S1B_EW_GRDM_1SDH_20180621T214028_20180621T214132_011477_01516D_E6E0.SAFE.zip
# Found TIFF file: S1B_EW_GRDM_1SDH_20180621T214028_20180621T214132_011477_01516D_E6E0.SAFE/measurement/s1b-ew-grd-hh-20180621t214028-20180621t214132-011477-01516d-001.tiff
# Reading hh TIFF data into memory...
# Finished reading hh data.
# Found TIFF file: S1B_EW_GRDM_1SDH_20180621T214028_20180621T214132_011477_01516D_E6E0.SAFE/measurement/s1b-ew-grd-hv-20180621t214028-20180621t214132-011477-01516d-002.tiff
# Reading hv TIFF data into memory...
# Finished reading hv data.
# Processed 2 TIFF files from S1B_EW_GRDM_1SDH_20180621T214028_20180621T214132_011477_01516D_E6E0.SAFE.zip.
# Created xarray Dataset for S1B_EW_GRDM_1SDH_20180621T214028_20180621T214132_011477_01516D_E6E0.SAFE.zip.
# Saved NetCDF: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/netcdfs/S1B_EW_GRDM_1SDH_20180621T214028_20180621T214132_011477_01516D_E6E0.SAFE.nc
# Completed 1/510 ZIP files.
#
# Processing ZIP file: S1A_EW_GRDM_1SDH_20180907T120359_20180907T120459_023592_0291F2_C233.SAFE.zip
# Found TIFF file: S1A_EW_GRDM_1SDH_20180907T120359_20180907T120459_023592_0291F2_C233.SAFE/measurement/s1a-ew-grd-hh-20180907t120359-20180907t120459-023592-0291f2-001.tiff
# Reading hh TIFF data into memory...
# Finished reading hh data.
# Found TIFF file: S1A_EW_GRDM_1SDH_20180907T120359_20180907T120459_023592_0291F2_C233.SAFE/measurement/s1a-ew-grd-hv-20180907t120359-20180907t120459-023592-0291f2-002.tiff
# Reading hv TIFF data into memory...
# Finished reading hv data.
# Processed 2 TIFF files from S1A_EW_GRDM_1SDH_20180907T120359_20180907T120459_023592_0291F2_C233.SAFE.zip.
# Created xarray Dataset for S1A_EW_GRDM_1SDH_20180907T120359_20180907T120459_023592_0291F2_C233.SAFE.zip.
# Saved NetCDF: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/netcdfs/S1A_EW_GRDM_1SDH_20180907T120359_20180907T120459_023592_0291F2_C233.SAFE.nc
# Completed 2/510 ZIP files.
#
# Processing ZIP file: S1B_EW_GRDM_1SDH_20180922T113859_20180922T114003_012827_017AEB_9655.SAFE.zip
# Found TIFF file: S1B_EW_GRDM_1SDH_20180922T113859_20180922T114003_012827_017AEB_9655.SAFE/measurement/s1b-ew-grd-hh-20180922t113859-20180922t114003-012827-017aeb-001.tiff
# Reading hh TIFF data into memory...
# Finished reading hh data.
# Found TIFF file: S1B_EW_GRDM_1SDH_20180922T113859_20180922T114003_012827_017AEB_9655.SAFE/measurement/s1b-ew-grd-hv-20180922t113859-20180922t114003-012827-017aeb-002.tiff
# Reading hv TIFF data into memory...
# Finished reading hv data.
# Processed 2 TIFF files from S1B_EW_GRDM_1SDH_20180922T113859_20180922T114003_012827_017AEB_9655.SAFE.zip.
# Created xarray Dataset for S1B_EW_GRDM_1SDH_20180922T113859_20180922T114003_012827_017AEB_9655.SAFE.zip.
# Saved NetCDF: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/netcdfs/S1B_EW_GRDM_1SDH_20180922T113859_20180922T114003_012827_017AEB_9655.SAFE.nc
# Completed 3/510 ZIP files.
#
# Processing ZIP file: S1B_EW_GRDM_1SDH_20200628T205222_20200628T205322_022239_02A352_76A5.SAFE.zip
# Found TIFF file: S1B_EW_GRDM_1SDH_20200628T205222_20200628T205322_022239_02A352_76A5.SAFE/measurement/s1b-ew-grd-hh-20200628t205222-20200628t205322-022239-02a352-001.tiff
# Reading hh TIFF data into memory...
# Finished reading hh data.
# Found TIFF file: S1B_EW_GRDM_1SDH_20200628T205222_20200628T205322_022239_02A352_76A5.SAFE/measurement/s1b-ew-grd-hv-20200628t205222-20200628t205322-022239-02a352-002.tiff
# Reading hv TIFF data into memory...
# Finished reading hv data.
# Processed 2 TIFF files from S1B_EW_GRDM_1SDH_20200628T205222_20200628T205322_022239_02A352_76A5.SAFE.zip.
# Created xarray Dataset for S1B_EW_GRDM_1SDH_20200628T205222_20200628T205322_022239_02A352_76A5.SAFE.zip.
# Saved NetCDF: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/netcdfs/S1B_EW_GRDM_1SDH_20200628T205222_20200628T205322_022239_02A352_76A5.SAFE
510 ZIP files.
#
# Processing ZIP file: S1B_EW_GRDM_1SDH_20180702T112340_20180702T112357_011631_01562E_7237.SAFE.zip
# Found TIFF file: S1B_EW_GRDM_1SDH_20180702T112340_20180702T112357_011631_01562E_7237.SAFE/measurement/s1b-ew-grd-hh-20180702t112340-20180702t112357-011631-01562e-001.tiff
# Reading hh TIFF data into memory...
# Finished reading hh data.
# Found TIFF file: S1B_EW_GRDM_1SDH_20180702T112340_20180702T112357_011631_01562E_7237.SAFE/measurement/s1b-ew-grd-hv-20180702t112340-20180702t112357-011631-01562e-002.tiff
# Reading hv TIFF data into memory...
# Finished reading hv data.
# Processed 2 TIFF files from S1B_EW_GRDM_1SDH_20180702T112340_20180702T112357_011631_01562E_7237.SAFE.zip.
# Created xarray Dataset for S1B_EW_GRDM_1SDH_20180702T112340_20180702T112357_011631_01562E_7237.SAFE.zip.
# Saved NetCDF: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/netcdfs/S1B_EW_GRDM_1SDH_20180702T112340_20180702T112357_011631_01562E_7237.SAFE.nc
# Completed 502/510 ZIP files.
#
# Processing ZIP file: S1B_EW_GRDM_1SDH_20190228T214134_20190228T214234_015152_01C55A_74F1.SAFE.zip
# Found TIFF file: S1B_EW_GRDM_1SDH_20190228T214134_20190228T214234_015152_01C55A_74F1.SAFE/measurement/s1b-ew-grd-hh-20190228t214134-20190228t214234-015152-01c55a-001.tiff
# Reading hh TIFF data into memory...
# Finished reading hh data.
# Found TIFF file: S1B_EW_GRDM_1SDH_20190228T214134_20190228T214234_015152_01C55A_74F1.SAFE/measurement/s1b-ew-grd-hv-20190228t214134-20190228t214234-015152-01c55a-002.tiff
# Reading hv TIFF data into memory...
# Finished reading hv data.
# Processed 2 TIFF files from S1B_EW_GRDM_1SDH_20190228T214134_20190228T214234_015152_01C55A_74F1.SAFE.zip.
# Created xarray Dataset for S1B_EW_GRDM_1SDH_20190228T214134_20190228T214234_015152_01C55A_74F1.SAFE.zip.
# Saved NetCDF: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/netcdfs/S1B_EW_GRDM_1SDH_20190228T214134_20190228T214234_015152_01C55A_74F1.SAFE.nc
# Completed 503/510 ZIP files.
#
# Processing ZIP file: S1B_EW_GRDM_1SDH_20211007T081021_20211007T081121_029027_0376B1_B417.SAFE.zip
# Found TIFF file: S1B_EW_GRDM_1SDH_20211007T081021_20211007T081121_029027_0376B1_B417.SAFE/measurement/s1b-ew-grd-hh-20211007t081021-20211007t081121-029027-0376b1-001.tiff
# Reading hh TIFF data into memory...
# Finished reading hh data.
# Found TIFF file: S1B_EW_GRDM_1SDH_20211007T081021_20211007T081121_029027_0376B1_B417.SAFE/measurement/s1b-ew-grd-hv-20211007t081021-20211007t081121-029027-0376b1-002.tiff
# Reading hv TIFF data into memory...
# Finished reading hv data.
# Processed 2 TIFF files from S1B_EW_GRDM_1SDH_20211007T081021_20211007T081121_029027_0376B1_B417.SAFE.zip.
# Created xarray Dataset for S1B_EW_GRDM_1SDH_20211007T081021_20211007T081121_029027_0376B1_B417.SAFE.zip.
# Saved NetCDF: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/netcdfs/S1B_EW_GRDM_1SDH_20211007T081021_20211007T081121_029027_0376B1_B417.SAFE.nc
# Completed 504/510 ZIP files.
#
# Processing ZIP file: S1A_EW_GRDM_1SDH_20190924T121820_20190924T121920_029163_034FB1_BD47.SAFE.zip
# Found TIFF file: S1A_EW_GRDM_1SDH_20190924T121820_20190924T121920_029163_034FB1_BD47.SAFE/measurement/s1a-ew-grd-hh-20190924t121820-20190924t121920-029163-034fb1-001.tiff
# Reading hh TIFF data into memory...
# Finished reading hh data.
# Found TIFF file: S1A_EW_GRDM_1SDH_20190924T121820_20190924T121920_029163_034FB1_BD47.SAFE/measurement/s1a-ew-grd-hv-20190924t121820-20190924t121920-029163-034fb1-002.tiff
# Reading hv TIFF data into memory...
# Finished reading hv data.
# Processed 2 TIFF files from S1A_EW_GRDM_1SDH_20190924T121820_20190924T121920_029163_034FB1_BD47.SAFE.zip.
# Created xarray Dataset for S1A_EW_GRDM_1SDH_20190924T121820_20190924T121920_029163_034FB1_BD47.SAFE.zip.
# Saved NetCDF: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/netcdfs/S1A_EW_GRDM_1SDH_20190924T121820_20190924T121920_029163_034FB1_BD47.SAFE.nc
# Completed 505/510 ZIP files.
#
# Processing ZIP file: S1A_EW_GRDM_1SDH_20210128T103956_20210128T104100_036337_044383_4266.SAFE.zip
# Found TIFF file: S1A_EW_GRDM_1SDH_20210128T103956_20210128T104100_036337_044383_4266.SAFE/measurement/s1a-ew-grd-hh-20210128t103956-20210128t104100-036337-044383-001.tiff
# Reading hh TIFF data into memory...
# Finished reading hh data.
# Found TIFF file: S1A_EW_GRDM_1SDH_20210128T103956_20210128T104100_036337_044383_4266.SAFE/measurement/s1a-ew-grd-hv-20210128t103956-20210128t104100-036337-044383-002.tiff
# Reading hv TIFF data into memory...
# Finished reading hv data.
# Processed 2 TIFF files from S1A_EW_GRDM_1SDH_20210128T103956_20210128T104100_036337_044383_4266.SAFE.zip.
# Created xarray Dataset for S1A_EW_GRDM_1SDH_20210128T103956_20210128T104100_036337_044383_4266.SAFE.zip.
# Saved NetCDF: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/netcdfs/S1A_EW_GRDM_1SDH_20210128T103956_20210128T104100_036337_044383_4266.SAFE.nc
# Completed 506/510 ZIP files.
#
# Processing ZIP file: S1B_EW_GRDM_1SDH_20210901T081020_20210901T081120_028502_0366AD_AED8.SAFE.zip
# Found TIFF file: S1B_EW_GRDM_1SDH_20210901T081020_20210901T081120_028502_0366AD_AED8.SAFE/measurement/s1b-ew-grd-hh-20210901t081020-20210901t081120-028502-0366ad-001.tiff
# Reading hh TIFF data into memory...
# Finished reading hh data.
# Found TIFF file: S1B_EW_GRDM_1SDH_20210901T081020_20210901T081120_028502_0366AD_AED8.SAFE/measurement/s1b-ew-grd-hv-20210901t081020-20210901t081120-028502-0366ad-002.tiff
# Reading hv TIFF data into memory...
# Finished reading hv data.
# Processed 2 TIFF files from S1B_EW_GRDM_1SDH_20210901T081020_20210901T081120_028502_0366AD_AED8.SAFE.zip.
# Created xarray Dataset for S1B_EW_GRDM_1SDH_20210901T081020_20210901T081120_028502_0366AD_AED8.SAFE.zip.
# Saved NetCDF: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/netcdfs/S1B_EW_GRDM_1SDH_20210901T081020_20210901T081120_028502_0366AD_AED8.SAFE.nc
# Completed 507/510 ZIP files.
#
# Processing ZIP file: S1A_EW_GRDM_1SDH_20180306T101622_20180306T101722_020893_023D76_206D.SAFE.zip
# Found TIFF file: S1A_EW_GRDM_1SDH_20180306T101622_20180306T101722_020893_023D76_206D.SAFE/measurement/s1a-ew-grd-hh-20180306t101622-20180306t101722-020893-023d76-001.tiff
# Reading hh TIFF data into memory...
# Finished reading hh data.
# Found TIFF file: S1A_EW_GRDM_1SDH_20180306T101622_20180306T101722_020893_023D76_206D.SAFE/measurement/s1a-ew-grd-hv-20180306t101622-20180306t101722-020893-023d76-002.tiff
# Reading hv TIFF data into memory...
# Finished reading hv data.
# Processed 2 TIFF files from S1A_EW_GRDM_1SDH_20180306T101622_20180306T101722_020893_023D76_206D.SAFE.zip.
# Created xarray Dataset for S1A_EW_GRDM_1SDH_20180306T101622_20180306T101722_020893_023D76_206D.SAFE.zip.
# Saved NetCDF: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/netcdfs/S1A_EW_GRDM_1SDH_20180306T101622_20180306T101722_020893_023D76_206D.SAFE.nc
# Completed 508/510 ZIP files.
#
# Processing ZIP file: S1A_EW_GRDM_1SDH_20190802T183536_20190802T183640_028394_033568_3716.SAFE.zip
# Found TIFF file: S1A_EW_GRDM_1SDH_20190802T183536_20190802T183640_028394_033568_3716.SAFE/measurement/s1a-ew-grd-hh-20190802t183536-20190802t183640-028394-033568-001.tiff
# Reading hh TIFF data into memory...
# Finished reading hh data.
# Found TIFF file: S1A_EW_GRDM_1SDH_20190802T183536_20190802T183640_028394_033568_3716.SAFE/measurement/s1a-ew-grd-hv-20190802t183536-20190802t183640-028394-033568-002.tiff
# Reading hv TIFF data into memory...
# Finished reading hv data.
# Processed 2 TIFF files from S1A_EW_GRDM_1SDH_20190802T183536_20190802T183640_028394_033568_3716.SAFE.zip.
# Created xarray Dataset for S1A_EW_GRDM_1SDH_20190802T183536_20190802T183640_028394_033568_3716.SAFE.zip.
# Saved NetCDF: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/netcdfs/S1A_EW_GRDM_1SDH_20190802T183536_20190802T183640_028394_033568_3716.SAFE.nc
# Completed 509/510 ZIP files.
#
# Processing ZIP file: S1A_EW_GRDM_1SDH_20210707T082619_20210707T082723_038669_049030_65A2.SAFE.zip
# Found TIFF file: S1A_EW_GRDM_1SDH_20210707T082619_20210707T082723_038669_049030_65A2.SAFE/measurement/s1a-ew-grd-hh-20210707t082619-20210707t082723-038669-049030-001.tiff
# Reading hh TIFF data into memory...
# Finished reading hh data.
# Found TIFF file: S1A_EW_GRDM_1SDH_20210707T082619_20210707T082723_038669_049030_65A2.SAFE/measurement/s1a-ew-grd-hv-20210707t082619-20210707t082723-038669-049030-002.tiff
# Reading hv TIFF data into memory...
# Finished reading hv data.
# Processed 2 TIFF files from S1A_EW_GRDM_1SDH_20210707T082619_20210707T082723_038669_049030_65A2.SAFE.zip.
# Created xarray Dataset for S1A_EW_GRDM_1SDH_20210707T082619_20210707T082723_038669_049030_65A2.SAFE.zip.
# Saved NetCDF: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/netcdfs/S1A_EW_GRDM_1SDH_20210707T082619_20210707T082723_038669_049030_65A2.SAFE.nc
# Completed 510/510 ZIP files.
# All TIFF files have been saved in NetCDF files!

# %% [markdown]
# ## Downsample Images

# %%
import os
import xarray as xr
import numpy as np

# Path to original and downsampled NetCDF files
netcdf_dir = r'ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/netcdfs/'
downsampled_dir = r'ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled/'

# Ensure the downsampled directory exists
os.makedirs(downsampled_dir, exist_ok=True)

# Downsample function
def downsample_image(image, scale_factor=2):
    """Downsamples the image using a 2x2 averaging kernel."""
    if image.shape[0] % scale_factor != 0 or image.shape[1] % scale_factor != 0:
        image = image[:image.shape[0] - image.shape[0] % scale_factor,
                      :image.shape[1] - image.shape[1] % scale_factor]

    downsampled_image = image.reshape(
        (image.shape[0] // scale_factor, scale_factor, 
         image.shape[1] // scale_factor, scale_factor)).mean(axis=(1, 3))
    
    return downsampled_image

# Loop through all NetCDF files
for file_name in os.listdir(netcdf_dir):
    if file_name.endswith('.nc'):
        netcdf_path = os.path.join(netcdf_dir, file_name)
        downsampled_netcdf_path = os.path.join(downsampled_dir, file_name)  # Save to downsampled folder
        
        try:
            # Open the original NetCDF file in read-only mode
            with xr.open_dataset(netcdf_path, mode='r') as ds:
                # Create a new dataset for downsampled data
                downsampled_ds = xr.Dataset()

                # Downsample and save the 'hh' and 'hv' datasets
                if 'hh' in ds.variables:
                    hh_image = ds['hh'].values  # Extract original image data
                    downsampled_hh = downsample_image(hh_image)  # Downsample it
                    # Create a new variable in the downsampled dataset with downsampled data
                    downsampled_ds['hh'] = (('y', 'x'), downsampled_hh)

                if 'hv' in ds.variables:
                    hv_image = ds['hv'].values  # Extract original image data
                    downsampled_hv = downsample_image(hv_image)  # Downsample it
                    # Create a new variable in the downsampled dataset with downsampled data
                    downsampled_ds['hv'] = (('y', 'x'), downsampled_hv)

                # Carry over the attributes from the original dataset (optional)
                downsampled_ds.attrs = ds.attrs

                # Optionally, copy over other metadata or dimensions if needed
                downsampled_ds['x'] = (('x',), np.arange(downsampled_hh.shape[1]))
                downsampled_ds['y'] = (('y',), np.arange(downsampled_hh.shape[0]))

                # Save the downsampled dataset to the new NetCDF file
                downsampled_ds.to_netcdf(downsampled_netcdf_path)
                print(f"Downsampled file saved as: {downsampled_netcdf_path}")
                
        except Exception as e:
            print(f"Error processing file {file_name}: {e}")

print("Downsampling completed and saved in the downsampled directory.")
# Out:
# Downsampled file saved as: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled/S1A_EW_GRDM_1SDH_20210318T080139_20210318T080244_037050_045C47_5A55.SAFE.nc
# Downsampled file saved as: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled/S1A_EW_GRDM_1SDH_20200213T203546_20200213T203651_031239_0397B5_2082.SAFE.nc
# Downsampled file saved as: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled/S1B_EW_GRDM_1SDH_20210215T072003_20210215T072103_025614_030D70_5663.SAFE.nc
# Downsampled file saved as: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled/S1A_EW_GRDM_1SDH_20211029T203602_20211029T203706_040339_04C7D6_0B08.SAFE.nc
# Downsampled file saved as: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled/S1A_EW_GRDM_1SDH_20210411T174728_20210411T174833_037406_04689E_23A6.SAFE.nc
# Downsampled file saved as: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled/S1B_EW_GRDM_1SDH_20190831T130738_20190831T130838_017830_0218E5_2A1F.SAFE.nc
# Downsampled file saved as: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled/S1A_EW_GRDM_1SDH_20211126T102442_20211126T102546_040741_04D5C7_EF8A.SAFE.nc
# Downsampled file saved as: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled/S1A_EW_GRDM_1SDH_20200227T104053_20200227T104153_031437_039E85_6FC4.SAFE.nc
# Downsampled file saved as: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled/S1B_EW_GRDM_1SDH_20200814T121425_20200814T121525_022919_02B812_6374.SAFE.nc
# Downsampled file saved as: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled/S1B_EW_GRDM_1SDH_20200201T212408_20200201T212512_020081_02601C_BE87.SAFE.nc
# Downsampled file saved as: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled/S1A_EW_GRDM_1SDH_20190225T202729_20190225T202833_026091_02E911_D516.SAFE.nc
# Downsampled file saved as: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled/S1B_EW_GRDM_1SDH_20200925T080407_20200925T080507_023529_02CB26_1B10.SAFE.nc
# Downsampled file saved as: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled/S1A_EW_GRDM_1SDH_20200930T201936_20200930T202040_034593_040707_5603.SAFE.nc
# Downsampled file saved as: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled/S1B_EW_GRDM_1SDH_20210113T110732_20210113T110832_025135_02FE21_10B1.SAFE.nc
# Downsampled file saved as: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled/S1B_EW_GRDM_1SDH_20181207T110721_20181207T110821_013935_019DA6_E925.SAFE.nc
# Downsampled file saved as: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled/S1B_EW_GRDM_1SDH_20201112T080407_20201112T080507_024229_02E0F2_8F67.SAFE.nc
# Downsampled file saved as: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled/S1A_EW_GRDM_1SDH_20210727T104206_20210727T104306_038962_0498E2_F32D.SAFE.nc
# Downsampled file saved as: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled/S1B_EW_GRDM_1SDH_20211206T211031_20211206T211131_029910_039211_6CE1.SAFE.nc
# Downsampled file saved as: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled/S1A_EW_GRDM_1SDH_20191006T122020_20191006T122120_029338_0355BC_DAC7.SAFE.nc
# Downsampled file saved as: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled/S1A_EW_GRDM_1SDH_20210819T082114_20210819T082214_039296_04A3F0_CAD6.SAFE.nc
# Downsampled file saved as: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled/S1A_EW_GRDM_1SDH_20210714T114034_20210714T114134_038773_049342_A7E5.SAFE.nc
# Downsampled file saved as: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled/S1B_EW_GRDM_1SDH_20190914T125119_20190914T125219_018034_021F31_69E3.SAFE.nc
# Downsampled file saved as: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled/S1A_EW_GRDM_1SDH_20201119T070533_20201119T070633_035314_042009_DCE3.SAFE.nc
# Downsampled file saved as: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled/S1B_EW_GRDM_1SDH_20191013T210446_20191013T210504_018462_022C8C_1844.SAFE.nc
# Downsampled file saved as: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled/S1B_EW_GRDM_1SDH_20210202T211745_20210202T211845_025433_03078E_224C.SAFE.nc
# Downsampled file saved as: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled/S1A_EW_GRDM_1SDH_20211220T102441_20211220T102545_041091_04E1B6_9AA6.SAFE.nc
# Downsampled file saved as: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled/S1B_EW_GRDM_1SDH_20180919T125113_20180919T125213_012784_017993_3880.SAFE.nc
# Downsampled file saved as: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled/S1B_EW_GRDM_1SDH_20200928T114452_20200928T114552_023575_02CCAE_559F.SAFE.nc
# Downsampled file saved as: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled/S1A_EW_GRDM_1SDH_20210127T212142_20210127T212242_036329_04434A_D69F.SAFE.nc
# Downsampled file saved as: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled/S1B_EW_GRDM_1SDH_20180824T130731_20180824T130831_012405_016DF4_541A.SAFE.nc
# Downsampled file saved as: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled/S1A_EW_GRDM_1SDH_20191201T205227_20191201T205332_030160_037250_2BC8.SAFE.nc
# Downsampled file saved as: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled/S1B_EW_GRDM_1SDH_20191018T130839_20191018T130933_018530_022EA4_4267.SAFE.nc
# Downsampled file saved as: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled/S1B_EW_GRDM_1SDH_20210205T214147_20210205T214247_025477_030916_A2BB.SAFE.nc
# Downsampled file saved as: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled/S1A_EW_GRDM_1SDH_20211006T212151_20211006T212251_040004_04BC3D_A399.SAFE.nc
# Downsampled file saved as: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled/S1A_EW_GRDM_1SDH_20191115T082916_20191115T083016_029919_0369F2_5192.SAFE.nc
# Downsampled file saved as: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled/S1B_EW_GRDM_1SDH_20210314T110731_20210314T110831_026010_031A75_4981.SAFE.nc
# Downsampled file saved as: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled/S1B_EW_GRDM_1SDH_20200726T184242_20200726T184342_022646_02AFB5_0CC7.SAFE.nc
# Downsampled file saved as: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled/S1A_EW_GRDM_1SDH_20
SAFE.nc
# Downsampled file saved as: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled/S1A_EW_GRDM_1SDH_20190709T121404_20190709T121504_028040_032AB0_515C.SAFE.nc
# Downsampled file saved as: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled/S1B_EW_GRDM_1SDH_20210129T103213_20210129T103313_025368_03057A_F615.SAFE.nc
# Downsampled file saved as: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled/S1B_EW_GRDM_1SDH_20200326T203446_20200326T203551_020868_027922_F9F6.SAFE.nc
# Downsampled file saved as: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled/S1B_EW_GRDM_1SDH_20180621T214028_20180621T214132_011477_01516D_E6E0.SAFE.nc
# Downsampled file saved as: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled/S1A_EW_GRDM_1SDH_20200809T205232_20200809T205336_033835_03EC5F_50FC.SAFE.nc
# Downsampled file saved as: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled/S1A_EW_GRDM_1SDH_20190119T101118_20190119T101218_025545_02D565_303A.SAFE.nc
# Downsampled file saved as: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled/S1B_EW_GRDM_1SDH_20191028T132259_20191028T132359_018676_023331_72E3.SAFE.nc
# Downsampling completed and saved in the downsampled directory.

# %% [markdown]
# ## Find Matching Files; Resize to 1024; Save them

# %%
import os
import xarray as xr
import numpy as np
from skimage.transform import resize
from scipy.ndimage import zoom

# Paths to your directories
train_dir = r'ai4arctic-sea-ice-challenge-ready-to-train/v2/ready-to-train_train/'
downsampled_dir = r'ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled/'
output_dir = r'ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_final/'

# Create the output directory if it doesn't exist
os.makedirs(output_dir, exist_ok=True)

# Function to resize arrays (HH, HV)
def resize_array(data_array, new_shape=(1024, 1024)):
    return resize(data_array, new_shape, mode='reflect', anti_aliasing=True)

# Function to resize binary ice map (SOD)
def resize_array_binary(data_array, new_shape=(1024, 1024)):
    zoom_factors = (new_shape[0] / data_array.shape[0], new_shape[1] / data_array.shape[1])
    return zoom(data_array, zoom_factors, order=0)

# Get list of training and downsampled files
training_files = [f for f in os.listdir(train_dir) if f.endswith(".nc")]
downsampled_files = [f for f in os.listdir(downsampled_dir) if f.endswith(".nc")]

# Loop through training files
for training_file in training_files:
    # Extract the date part before the first underscore
    training_date = training_file.split('_')[0]

    # Find matching downsampled file
    matching_downsampled = None
    for downsampled_file in downsampled_files:
        if training_date in downsampled_file:
            matching_downsampled = downsampled_file
            break

    # If a matching downsampled file is found
    if matching_downsampled:
        print(f"Matching files found: {training_file} and {matching_downsampled}")
        
        # Open both NetCDF files
        training_nc = xr.open_dataset(os.path.join(train_dir, training_file))
        downsampled_nc = xr.open_dataset(os.path.join(downsampled_dir, matching_downsampled))

        # Extract SOD from training file
        if 'SOD' in training_nc:
            sod_data = training_nc['SOD'].values
            sod_resized = resize_array_binary(sod_data)

        # Extract HH and HV from downsampled file
        if 'hh' in downsampled_nc and 'hv' in downsampled_nc:
            hh_data = downsampled_nc['hh'].values
            hv_data = downsampled_nc['hv'].values
            hh_resized = resize_array(hh_data)
            hv_resized = resize_array(hv_data)

            # Create a new xarray Dataset
            new_ds = xr.Dataset({
                'hh': (['y', 'x'], hh_resized),
                'hv': (['y', 'x'], hv_resized),
                'SOD': (['y', 'x'], sod_resized)
            })

            # Define the output file path
            output_file = os.path.join(output_dir, f"{training_date}_resized.nc")

            # Save the new dataset to NetCDF
            new_ds.to_netcdf(output_file, mode='w')
            print(f"Saved resized NetCDF: {output_file}")
        
        # Close the datasets
        training_nc.close()
        downsampled_nc.close()
    else:
        print(f"No matching downsampled file found for {training_file}")

print("All matching files have been processed and saved in the output directory.")
# Out:
# Matching files found: 20201229T104119_dmi_prep.nc and S1B_EW_GRDM_1SDH_20201229T104119_20201229T104219_024916_02F703_C262.SAFE.nc
# Saved resized NetCDF: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_final/20201229T104119_resized.nc
# Matching files found: 20190831T144552_cis_prep.nc and S1B_EW_GRDM_1SDH_20190831T144552_20190831T144652_017831_0218EB_1D2C.SAFE.nc
# Saved resized NetCDF: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_final/20190831T144552_resized.nc
# Matching files found: 20190612T101220_cis_prep.nc and S1A_EW_GRDM_1SDH_20190612T101120_20190612T101220_027645_031ECD_9403.SAFE.nc
# Saved resized NetCDF: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_final/20
.SAFE.nc
# Saved resized NetCDF: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_final/20180821T165031_resized.nc
# Matching files found: 20200124T102732_cis_prep.nc and S1A_EW_GRDM_1SDH_20200124T102732_20200124T102834_030941_038D5E_C305.SAFE.nc
# Saved resized NetCDF: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_final/20200124T102732_resized.nc
# Matching files found: 20210116T193208_dmi_prep.nc and S1B_EW_GRDM_1SDH_20210116T193108_20210116T193208_025184_02FF9F_DA70.SAFE.nc
# Saved resized NetCDF: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_final/20210116T193208_resized.nc
# Matching files found: 20200807T122136_cis_prep.nc and S1B_EW_GRDM_1SDH_20200807T122136_20200807T122236_022817_02B4EB_0C44.SAFE.nc
# Saved resized NetCDF: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_final/20200807T122136_resized.nc
# Matching files found: 20210407T101841_cis_prep.nc and S1A_EW_GRDM_1SDH_20210407T101841_20210407T101941_037343_046676_BEEF.SAFE.nc
# Saved resized NetCDF: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_final/20210407T101841_resized.nc
# Matching files found: 20211222T105953_cis_prep.nc and S1B_EW_GRDM_1SDH_20211222T105953_20211222T110047_030137_039940_D955.SAFE.nc
# Saved resized NetCDF: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_final/20211222T105953_resized.nc
# Matching files found: 20180427T103155_dmi_prep.nc and S1B_EW_GRDM_1SDH_20180427T103155_20180427T103255_010668_0137A5_EDBE.SAFE.nc
# Saved resized NetCDF: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_final/20180427T103155_resized.nc
# Matching files found: 20200921T164824_cis_prep.nc and S1B_EW_GRDM_1SDH_20200921T164824_20200921T164924_023476_02C98A_5E28.SAFE.nc
# Saved resized NetCDF: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_final/20200921T164824_resized.nc
# Matching files found: 20210429T080105_dmi_prep.nc and S1B_EW_GRDM_1SDH_20210429T080105_20210429T080205_026679_032FAF_A971.SAFE.nc
# Saved resized NetCDF: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_final/20210429T080105_resized.nc
# Matching files found: 20211014T210254_dmi_prep.nc and S1B_EW_GRDM_1SDH_20211014T210254_20211014T210358_029137_037A24_8211.SAFE.nc
# Saved resized NetCDF: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_final/20211014T210254_resized.nc
# Matching files found: 20200628T205222_dmi_prep.nc and S1B_EW_GRDM_1SDH_20200628T205222_20200628T205322_022239_02A352_76A5.SAFE.nc
# Saved resized NetCDF: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_final/20200628T205222_resized.nc
# Matching files found: 20210912T212151_dmi_prep.nc and S1A_EW_GRDM_1SDH_20210912T212151_20210912T212251_039654_04B042_444B.SAFE.nc
# Saved resized NetCDF: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_final/20210912T212151_resized.nc
# Matching files found: 20190511T120101_dmi_prep.nc and S1B_EW_GRDM_1SDH_20190511T120101_20190511T120201_016196_01E7A7_7F2F.SAFE.nc
# Saved resized NetCDF: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_final/20190511T120101_resized.nc
# Matching files found: 20210113T101813_dmi_prep.nc and S1A_EW_GRDM_1SDH_20210113T101813_20210113T101913_036118_043BF4_53A2.SAFE.nc
# Saved resized NetCDF: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_final/20210113T101813_resized.nc
# Matching files found: 20190807T104254_cis_prep.nc and S1A_EW_GRDM_1SDH_20190807T104254_20190807T104354_028462_03376F_056D.SAFE.nc
# Saved resized NetCDF: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_final/20190807T104254_resized.nc
# Matching files found: 20190306T102625_cis_prep.nc and S1A_EW_GRDM_1SDH_20190306T102625_20190306T102725_026216_02ED7D_0CB8.SAFE.nc
# Saved resized NetCDF: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_final/20190306T102625_resized.nc
# Matching files found: 20190612T101120_cis_prep.nc and S1A_EW_GRDM_1SDH_20190612T101120_20190612T101220_027645_031ECD_9403.SAFE.nc
# Saved resized NetCDF: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_final/20190612T101120_resized.nc
# Matching files found: 20210628T192300_dmi_prep.nc and S1B_EW_GRDM_1SDH_20210628T192300_20210628T192400_027561_034A45_7C2F.SAFE.nc
# Saved resized NetCDF: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_final/20210628T192300_resized.nc
# Matching files found: 20180924T080254_dmi_prep.nc and S1B_EW_GRDM_1SDH_20180924T080254_20180924T080354_012854_017BBA_8BD3.SAFE.nc
# Saved resized NetCDF: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_final/20180924T080254_resized.nc
# Matching files found: 20180812T130731_cis_prep.nc and S1B_EW_GRDM_1SDH_20180812T130731_20180812T130831_012230_01688B_C8FF.SAFE.nc
# Saved resized NetCDF: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_final/20180812T130731_resized.nc
# Matching files found: 20211007T081021_dmi_prep.nc and S1B_EW_GRDM_1SDH_20211007T081021_20211007T081121_029027_0376B1_B417.SAFE.nc
# Saved resized NetCDF: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_final/20211007T081021_resized.nc
# Matching files found: 20190730T123155_cis_prep.nc and S1B_EW_GRDM_1SDH_20190730T123155_20190730T123255_017363_020A67_2B08.SAFE.nc
# Saved resized NetCDF: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_final/20190730T123155_resized.nc
# Matching files found: 20181028T123015_cis_prep.nc and S1A_EW_GRDM_1SDH_20181028T123015_20181028T123115_024336_02AA21_944F.SAFE.nc
# Saved resized NetCDF: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_final/20181028T123015_resized.nc
# Matching files found: 20211014T080213_dmi_prep.nc and S1B_EW_GRDM_1SDH_20211014T080213_20211014T080313_029129_0379D2_5BEA.SAFE.nc
# Saved resized NetCDF: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_final/20211014T080213_resized.nc
# Matching files found: 20200201T212408_cis_prep.nc and S1B_EW_GRDM_1SDH_20200201T212408_20200201T212512_020081_02601C_BE87.SAFE.nc
# Saved resized NetCDF: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_final/20200201T212408_resized.nc
# Matching files found: 20180821T151146_cis_prep.nc and S1A_EW_GRDM_1SDH_20180821T151146_20180821T151241_023346_028A15_F037.SAFE.nc
# Saved resized NetCDF: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_final/20180821T151146_resized.nc
# Matching files found: 20210709T085811_dmi_prep.nc and S1B_EW_GRDM_1SDH_20210709T085811_20210709T085911_027715_034EB5_56C3.SAFE.nc
# Saved resized NetCDF: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_final/20
SAFE.nc
# Saved resized NetCDF: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_final/20190809T120404_resized.nc
# Matching files found: 20200809T205232_dmi_prep.nc and S1A_EW_GRDM_1SDH_20200809T205232_20200809T205336_033835_03EC5F_50FC.SAFE.nc
# Saved resized NetCDF: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_final/20200809T205232_resized.nc
# Matching files found: 20200424T101936_cis_prep.nc and S1A_EW_GRDM_1SDH_20200424T101936_20200424T102036_032268_03BBA9_1CA8.SAFE.nc
# Saved resized NetCDF: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_final/20200424T101936_resized.nc
# Matching files found: 20190813T081112_dmi_prep.nc and S1A_EW_GRDM_1SDH_20190813T081112_20190813T081212_028548_033A7B_62C9.SAFE.nc
# Saved resized NetCDF: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_final/20190813T081112_resized.nc
# Matching files found: 20201117T193110_dmi_prep.nc and S1B_EW_GRDM_1SDH_20201117T193110_20201117T193210_024309_02E389_AF20.SAFE.nc
# Saved resized NetCDF: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_final/20201117T193110_resized.nc
# Matching files found: 20211002T210358_dmi_prep.nc and S1B_EW_GRDM_1SDH_20211002T210358_20211002T210458_028962_0374C8_A655.SAFE.nc
# Saved resized NetCDF: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_final/20211002T210358_resized.nc
# Matching files found: 20181102T212609_cis_prep.nc and S1B_EW_GRDM_1SDH_20181102T212609_20181102T212657_013431_018D9D_90C9.SAFE.nc
# Saved resized NetCDF: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_final/20181102T212609_resized.nc
# Matching files found: 20201211T210921_dmi_prep.nc and S1B_EW_GRDM_1SDH_20201211T210921_20201211T211025_024660_02EEBE_3A2D.SAFE.nc
# Saved resized NetCDF: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_final/20201211T210921_resized.nc
# Matching files found: 20211119T080313_dmi_prep.nc and S1B_EW_GRDM_1SDH_20211119T080313_20211119T080413_029654_0389FB_9317.SAFE.nc
# Saved resized NetCDF: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_final/20211119T080313_resized.nc
# Matching files found: 20180922T145543_cis_prep.nc and S1B_EW_GRDM_1SDH_20180922T145543_20180922T145626_012829_017AFC_5728.SAFE.nc
# Saved resized NetCDF: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_final/20180922T145543_resized.nc
# Matching files found: 20180926T124301_cis_prep.nc and S1B_EW_GRDM_1SDH_20180926T124301_20180926T124401_012886_017CBE_D62E.SAFE.nc
# Saved resized NetCDF: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_final/20180926T124301_resized.nc
# Matching files found: 20210828T205443_dmi_prep.nc and S1A_EW_GRDM_1SDH_20210828T205443_20210828T205544_039435_04A8A3_756F.SAFE.nc
# Saved resized NetCDF: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_final/20210828T205443_resized.nc
# Matching files found: 20200927T165045_cis_prep.nc and S1A_EW_GRDM_1SDH_20200927T165045_20200927T165146_034547_040561_1061.SAFE.nc
# Saved resized NetCDF: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_final/20200927T165045_resized.nc
# Matching files found: 20200831T211357_dmi_prep.nc and S1A_EW_GRDM_1SDH_20200831T211357_20200831T211510_034156_03F7AD_3998.SAFE.nc
# Saved resized NetCDF: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_final/20200831T211357_resized.nc
# All matching files have been processed and saved in the output directory.

# %% [markdown]
# ## Modify SOD

# %%
import os
import xarray as xr
import numpy as np
from skimage.transform import resize
from scipy.ndimage import zoom

# Paths to your directories
train_dir = r'ai4arctic-sea-ice-challenge-ready-to-train/v2/ready-to-train_train/'
downsampled_dir = r'ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled/'
output_dir = r'ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_final/'

# Create the output directory if it doesn't exist
os.makedirs(output_dir, exist_ok=True)

# Function to resize arrays (HH, HV)
def resize_array(data_array, new_shape=(1024, 1024)):
    return resize(data_array, new_shape, mode='reflect', anti_aliasing=True)

# Function to resize binary ice map (SOD)
def resize_array_binary(data_array, new_shape=(1024, 1024)):
    zoom_factors = (new_shape[0] / data_array.shape[0], new_shape[1] / data_array.shape[1])
    return zoom(data_array, zoom_factors, order=0)

# Function to modify SOD values
def modify_sod_values(sod_data):
    # Set values > 0 and < 255 to 1
    sod_data = np.where((sod_data > 0) & (sod_data < 255), 1, sod_data)
    # Set values of 255 to NaN
    sod_data = np.where(sod_data == 255, np.nan, sod_data)
    return sod_data

# Get list of training and downsampled files
training_files = [f for f in os.listdir(train_dir) if f.endswith(".nc")]
downsampled_files = [f for f in os.listdir(downsampled_dir) if f.endswith(".nc")]

# Loop through training files
for training_file in training_files:
    # Extract the date part before the first underscore
    training_date = training_file.split('_')[0]

    # Find matching downsampled file
    matching_downsampled = None
    for downsampled_file in downsampled_files:
        if training_date in downsampled_file:
            matching_downsampled = downsampled_file
            break

    # If a matching downsampled file is found
    if matching_downsampled:
        print(f"Matching files found: {training_file} and {matching_downsampled}")
        
        # Open both NetCDF files
        training_nc = xr.open_dataset(os.path.join(train_dir, training_file))
        downsampled_nc = xr.open_dataset(os.path.join(downsampled_dir, matching_downsampled))

        # Extract and modify SOD from training file
        if 'SOD' in training_nc:
            sod_data = training_nc['SOD'].values
            sod_modified = modify_sod_values(sod_data)
            sod_resized = resize_array_binary(sod_modified)

        # Extract HH and HV from downsampled file
        if 'hh' in downsampled_nc and 'hv' in downsampled_nc:
            hh_data = downsampled_nc['hh'].values
            hv_data = downsampled_nc['hv'].values
            hh_resized = resize_array(hh_data)
            hv_resized = resize_array(hv_data)

            # Create a new xarray Dataset
            new_ds = xr.Dataset({
                'hh': (['y', 'x'], hh_resized),
                'hv': (['y', 'x'], hv_resized),
                'SOD': (['y', 'x'], sod_resized)
            })

            # Define the output file path
            output_file = os.path.join(output_dir, f"{training_date}_resized.nc")

            # Save the new dataset to NetCDF
            new_ds.to_netcdf(output_file, mode='w')
            print(f"Saved modified and resized NetCDF: {output_file}")
        
        # Close the datasets
        training_nc.close()
        downsampled_nc.close()
    else:
        print(f"No matching downsampled file found for {training_file}")

print("All matching files have been processed and saved in the output directory.")
# Out:
# Matching files found: 20201229T104119_dmi_prep.nc and S1B_EW_GRDM_1SDH_20201229T104119_20201229T104219_024916_02F703_C262.SAFE.nc
# Saved modified and resized NetCDF: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_final/20201229T104119_resized.nc
# Matching files found: 20190831T144552_cis_prep.nc and S1B_EW_GRDM_1SDH_20190831T144552_20190831T144652_017831_0218EB_1D2C.SAFE.nc
# Saved modified and resized NetCDF: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_final/20190831T144552_resized.nc
# Matching files found: 20190612T101220_cis_prep.nc and S1A_EW_GRDM_1SDH_20190612T101120_20190612T101220_027645_031ECD_9403.SAFE.nc
# Saved modified and resized NetCDF: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_final/20190612T101220_resized.nc
# Matching files found: 20190411T102726_cis_prep.nc and S1A_EW_GRDM_1SDH_20190411T102726_20190411T102827_026741_0300CC_648B.SAFE.nc
# Saved modified and resized NetCDF: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_final/20190411T102726_resized.nc
# Matching files found: 20210509T104806_dmi_prep.nc and S1A_EW_GRDM_1SDH_20210509T104806_20210509T104910_037810_04766D_13A0.SAFE.nc
# Saved modified and resized NetCDF: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_final/20210509T104806_resized.nc
# Matching files found: 20210728T120930_dmi_prep.nc and S1B_EW_GRDM_1SDH_20210728T120930_20210728T121030_027994_0356F7_3E3E.SAFE.nc
# Saved modified and resized NetCDF: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_final/20210728T120930_resized.nc
# Matching files found: 20211105T193931_dmi_prep.nc and S1B_EW_GRDM_1SDH_20211105T193931_20211105T194031_029457_0383F2_F79A.SAFE.nc
# Saved modified and resized NetCDF: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_final/20211105T193931_resized.nc
# Matching files found: 20210625T194822_dmi_prep.nc and S1A_EW_GRDM_1SDH_20210625T194822_20210625T194922_038501_048B1E_B19B.SAFE.nc
# Saved modified and resized NetCDF: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_final/20210625T194822_resized.nc
# Matching files found: 20200203T104354_cis_prep.nc and S1A_EW_GRDM_1SDH_20200203T104354_20200203T104456_031087_039276_1827.SAFE.nc
# Saved modified and resized NetCDF: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_final/20200203T104354_resized.nc
# Matching files found: 20181202T185924_dmi_prep.nc and S1B_EW_GRDM_1SDH_20181202T185924_20181202T190029_013867_019B5B_C550.SAFE.nc
# Saved modified and resized NetCDF: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_final/20181202T185924_resized.nc
# Matching files found: 20190619T185115_dmi_prep.nc and S1B_EW_GRDM_1SDH_20190619T185115_20190619T185219_016769_01F8F8_AB64.SAFE.nc
# Saved modified and resized NetCDF: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_final/20190619T185115_resized.nc
# Matching files found: 20200412T110426_dmi_prep.nc and S1B_EW_GRDM_1SDH_20200412T110426_20200412T110526_021110_0280E9_15CC.SAFE.nc
# Saved modified and resized NetCDF: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_final/20200412T110426_resized.nc
# Matching files found: 20210715T211029_dmi_prep.nc and S1B_EW_GRDM_1SDH_20210715T211029_20210715T211129_027810_03518D_24AD.SAFE.nc
# Saved modified and resized NetCDF: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_final/20210715T211029_resized.nc
# Matching files found: 20210203T104018_dmi_prep.nc and S1B_EW_GRDM_1SDH_20210203T104018_20210203T104118_025441_0307CD_BC12.SAFE.nc
# Saved modified and resized NetCDF: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_final/20210203T104018_resized.nc
# Matching files found: 20210504T104101_dmi_prep.nc and S1A_EW_GRDM_1SDH_20210504T104101_20210504T104201_037737_04741E_D01D.SAFE.nc
# Saved modified and resized NetCDF: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_final/20210504T104101_resized.nc
# Matching files found: 20200424T102036_cis_prep.nc and S1A_EW_GRDM_1SDH_20200424T101936_20200424T102036_032268_03BBA9_1CA8.SAFE.nc
# Saved modified and resized NetCDF: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_final/20200424T102036_resized.nc
# Matching files found: 20200319T102035_cis_prep.nc and S1A_EW_GRDM_1SDH_20200319T102035_20200319T102058_031743_03A932_FB85.SAFE.nc
# Saved modified and resized NetCDF: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_final/20
SAFE.nc
# Saved modified and resized NetCDF: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_final/20180922T145543_resized.nc
# Matching files found: 20180926T124301_cis_prep.nc and S1B_EW_GRDM_1SDH_20180926T124301_20180926T124401_012886_017CBE_D62E.SAFE.nc
# Saved modified and resized NetCDF: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_final/20180926T124301_resized.nc
# Matching files found: 20210828T205443_dmi_prep.nc and S1A_EW_GRDM_1SDH_20210828T205443_20210828T205544_039435_04A8A3_756F.SAFE.nc
# Saved modified and resized NetCDF: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_final/20210828T205443_resized.nc
# Matching files found: 20200927T165045_cis_prep.nc and S1A_EW_GRDM_1SDH_20200927T165045_20200927T165146_034547_040561_1061.SAFE.nc
# Saved modified and resized NetCDF: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_final/20200927T165045_resized.nc
# Matching files found: 20200831T211357_dmi_prep.nc and S1A_EW_GRDM_1SDH_20200831T211357_20200831T211510_034156_03F7AD_3998.SAFE.nc
# Saved modified and resized NetCDF: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_final/20200831T211357_resized.nc
# All matching files have been processed and saved in the output directory.

# %% [markdown]
# ## Modify SOD; Manipulate HH and Hv and set to 0

# %%
import os
import xarray as xr
import numpy as np
from skimage.transform import resize

# Function to resize arrays
def resize_array(data_array, new_shape=(1024, 1024)):
    return resize(data_array, new_shape, mode='reflect', anti_aliasing=True)

# Directories
train_dir = r'ai4arctic-sea-ice-challenge-ready-to-train/v2/ready-to-train_train'
output_dir = r'ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_final/'
new_output_dir = r'ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/'

# Create the new output directory if it doesn't exist
os.makedirs(new_output_dir, exist_ok=True)

# Get list of training files
train_files = [f for f in os.listdir(train_dir) if f.endswith(".nc")]

# Loop through training files
for train_file in train_files:
    # Extract the date part between "clipped_" and the second underscore
    train_date = train_file.split('_')[0]

    # Find matching output file based on the date (assuming the output filenames contain the date)
    matching_output_file = None
    for output_file in os.listdir(output_dir):
        if train_date in output_file:
            matching_output_file = output_file
            break

    # If a matching output file is found
    if matching_output_file:
        print(f"Matching files found: {train_file} and {matching_output_file}")

        # Open the training and output files
        train_nc = xr.open_dataset(os.path.join(train_dir, train_file))
        output_nc = xr.open_dataset(os.path.join(output_dir, matching_output_file))

        # Resize the 'nersc_sar_primary' and 'nersc_sar_secondary' to 1024x1024
        resized_nersc_sar_primary = resize_array(train_nc['nersc_sar_primary'].values, new_shape=(1024, 1024))
        resized_nersc_sar_secondary = resize_array(train_nc['nersc_sar_secondary'].values, new_shape=(1024, 1024))

        # Modify hh based on 'nersc_sar_primary'
        hh = output_nc['hh'].data  # Extracting the underlying NumPy array
        hh = np.where(resized_nersc_sar_primary != 0, hh, 0)

        # Modify hv based on 'nersc_sar_secondary'
        hv = output_nc['hv'].data  # Extracting the underlying NumPy array
        hv = np.where(resized_nersc_sar_secondary != 0, hv, 0)

        # Get the 'sod' variable from the output file
        sod = output_nc['SOD'].data  # Extracting the underlying NumPy array

        # Create a new dataset with modified hh, hv, and existing sod
        new_output_nc = xr.Dataset(
            {
                'hh': (['x', 'y'], hh),
                'hv': (['x', 'y'], hv),
                'SOD': (['x', 'y'], sod)
            },
            coords={'x': output_nc['hh'].coords['x'], 'y': output_nc['hh'].coords['y']}
        )

        # Save the new dataset to the new output directory
        new_output_file = os.path.join(new_output_dir, matching_output_file)
        new_output_nc.to_netcdf(new_output_file)

        print(f"Saved modified file: {new_output_file}")

        # Close the datasets
        train_nc.close()
        output_nc.close()
        new_output_nc.close()

print("Processing complete.")
# Out:
# Matching files found: 20201229T104119_dmi_prep.nc and 20201229T104119_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20201229T104119_resized.nc
# Matching files found: 20190831T144552_cis_prep.nc and 20190831T144552_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20190831T144552_resized.nc
# Matching files found: 20190612T101220_cis_prep.nc and 20190612T101220_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20190612T101220_resized.nc
# Matching files found: 20190411T102726_cis_prep.nc and 20190411T102726_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20190411T102726_resized.nc
# Matching files found: 20210509T104806_dmi_prep.nc and 20210509T104806_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20210509T104806_resized.nc
# Matching files found: 20210728T120930_dmi_prep.nc and 20210728T120930_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20210728T120930_resized.nc
# Matching files found: 20211105T193931_dmi_prep.nc and 20211105T193931_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20211105T193931_resized.nc
# Matching files found: 20210625T194822_dmi_prep.nc and 20210625T194822_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20210625T194822_resized.nc
# Matching files found: 20200203T104354_cis_prep.nc and 20200203T104354_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20200203T104354_resized.nc
# Matching files found: 20181202T185924_dmi_prep.nc and 20181202T185924_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20181202T185924_resized.nc
# Matching files found: 20190619T185115_dmi_prep.nc and 20190619T185115_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20190619T185115_resized.nc
# Matching files found: 20200412T110426_dmi_prep.nc and 20200412T110426_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20200412T110426_resized.nc
# Matching files found: 20210715T211029_dmi_prep.nc and 20210715T211029_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20210715T211029_resized.nc
# Matching files found: 20210203T104018_dmi_prep.nc and 20210203T104018_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20210203T104018_resized.nc
# Matching files found: 20210504T104101_dmi_prep.nc and 20210504T104101_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20210504T104101_resized.nc
# Matching files found: 20200424T102036_cis_prep.nc and 20200424T102036_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20200424T102036_resized.nc
# Matching files found: 20200319T102035_cis_prep.nc and 20200319T102035_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20200319T102035_resized.nc
# Matching files found: 20210523T121414_cis_prep.nc and 20210523T121414_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20210523T121414_resized.nc
# Matching files found: 20180621T214132_cis_prep.nc and 20180621T214132_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20180621T214132_resized.nc
# Matching files found: 20190721T210442_cis_prep.nc and 20190721T210442_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20190721T210442_resized.nc
# Matching files found: 20191231T205545_dmi_prep.nc and 20191231T205545_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20191231T205545_resized.nc
# Matching files found: 20200517T214039_cis_prep.nc and 20200517T214039_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20200517T214039_resized.nc
# Matching files found: 20190129T205430_dmi_prep.nc and 20190129T205430_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20190129T205430_resized.nc
# Matching files found: 20210503T104433_dmi_prep.nc and 20210503T104433_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20210503T104433_resized.nc
# Matching files found: 20210621T211027_dmi_prep.nc and 20210621T211027_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20210621T211027_resized.nc
# Matching files found: 20210620T212146_dmi_prep.nc and 20210620T212146_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20210620T212146_resized.nc
# Matching files found: 20200208T114007_cis_prep.nc and 20200208T114007_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20200208T114007_resized.nc
# Matching files found: 20180902T124300_cis_prep.nc and 20180902T124300_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20180902T124300_resized.nc
# Matching files found: 20190519T194808_dmi_prep.nc and 20190519T194808_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20190519T194808_resized.nc
# Matching files found: 20210927T075405_dmi_prep.nc and 20210927T075405_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20210927T075405_resized.nc
# Matching files found: 20211225T121019_dmi_prep.nc and 20211225T121019_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20211225T121019_resized.nc
# Matching files found: 20200825T211225_dmi_prep.nc and 20200825T211225_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20200825T211225_resized.nc
# Matching files found: 20210707T082619_dmi_prep.nc and 20210707T082619_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20210707T082619_resized.nc
# Matching files found: 20211124T193116_dmi_prep.nc and 20211124T193116_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20211124T193116_resized.nc
# Matching files found: 20211216T082843_dmi_prep.nc and 20211216T082843_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20211216T082843_resized.nc
# Matching files found: 20210614T212049_dmi_prep.nc and 20210614T212049_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20210614T212049_resized.nc
# Matching files found: 20210121T082024_dmi_prep.nc and 20210121T082024_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20210121T082024_resized.nc
# Matching files found: 20210217T214246_cis_prep.nc and 20210217T214246_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20210217T214246_resized.nc
# Matching files found: 20201211T211025_dmi_prep.nc and 20201211T211025_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20201211T211025_resized.nc
# Matching files found: 20190522T210339_dmi_prep.nc and 20190522T210339_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20190522T210339_resized.nc
# Matching files found: 20200728T214147_cis_prep.nc and 20200728T214147_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20200728T214147_resized.nc
# Matching files found: 20181108T114951_cis_prep.nc and 20181108T114951_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20181108T114951_resized.nc
# Matching files found: 20210214T212045_dmi_prep.nc and 20210214T212045_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20210214T212045_resized.nc
# Matching files found: 20210812T123108_dmi_prep.nc and 20210812T123108_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20210812T123108_resized.nc
# Matching files found: 20201016T082722_dmi_prep.nc and 20201016T082722_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20201016T082722_resized.nc
# Matching files found: 20180929T081203_dmi_prep.nc and 20180929T081203_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20180929T081203_resized.nc
# Matching files found: 20201013T080348_dmi_prep.nc and 20201013T080348_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20201013T080348_resized.nc
# Matching files found: 20200624T212516_cis_prep.nc and 20200624T212516_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20200624T212516_resized.nc
# Matching files found: 20191103T114958_cis_prep.nc and 20191103T114958_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20191103T114958_resized.nc
# Matching files found: 20200110T104255_cis_prep.nc and 20200110T104255_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20200110T104255_resized.nc
# Matching files found: 20210124T214547_dmi_prep.nc and 20210124T214547_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20210124T214547_resized.nc
# Matching files found: 20200514T104800_dmi_prep.nc and 20200514T104800_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20200514T104800_resized.nc
# Matching files found: 20210806T194740_dmi_prep.nc and 20210806T194740_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20210806T194740_resized.nc
# Matching files found: 20211215T074546_dmi_prep.nc and 20211215T074546_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20211215T074546_resized.nc
# Matching files found: 20190826T152918_cis_prep.nc and 20190826T152918_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20190826T152918_resized.nc
# Matching files found: 20210706T115305_dmi_prep.nc and 20210706T115305_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20210706T115305_resized.nc
# Matching files found: 20180919T125113_cis_prep.nc and 20180919T125113_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20180919T125113_resized.nc
# Matching files found: 20210308T074624_dmi_prep.nc and 20210308T074624_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20210308T074624_resized.nc
# Matching files found: 20190129T205535_dmi_prep.nc and 20190129T205535_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20190129T205535_resized.nc
# Matching files found: 20210531T074627_dmi_prep.nc and 20210531T074627_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20210531T074627_resized.nc
# Matching files found: 20211110T082644_dmi_prep.nc and 20211110T082644_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20211110T082644_resized.nc
# Matching files found: 20200610T214040_cis_prep.nc and 20200610T214040_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20200610T214040_resized.nc
# Matching files found: 20180829T131543_cis_prep.nc and 20180829T131543_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20180829T131543_resized.nc
# Matching files found: 20190119T101218_cis_prep.nc and 20190119T101218_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20190119T101218_resized.nc
# Matching files found: 20190615T210440_dmi_prep.nc and 20190615T210440_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20190615T210440_resized.nc
# Matching files found: 20201112T080407_dmi_prep.nc and 20201112T080407_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20201112T080407_resized.nc
# Matching files found: 20190112T102000_cis_prep.nc and 20190112T102000_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20190112T102000_resized.nc
# Matching files found: 20210415T081724_dmi_prep.nc and 20210415T081724_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20210415T081724_resized.nc
# Matching files found: 20210520T082820_dmi_prep.nc and 20210520T082820_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20210520T082820_resized.nc
# Matching files found: 20210629T075348_dmi_prep.nc and 20210629T075348_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20210629T075348_resized.nc
# Matching files found: 20191016T155300_cis_prep.nc and 20191016T155300_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20191016T155300_resized.nc
# Matching files found: 20190524T101931_cis_prep.nc and 20190524T101931_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20190524T101931_resized.nc
# Matching files found: 20211025T081226_dmi_prep.nc and 20211025T081226_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20211025T081226_resized.nc
# Matching files found: 20200805T194819_dmi_prep.nc and 20200805T194819_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20200805T194819_resized.nc
# Matching files found: 20180327T103959_dmi_prep.nc and 20180327T103959_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20180327T103959_resized.nc
# Matching files found: 20190401T101117_cis_prep.nc and 20190401T101117_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20190401T101117_resized.nc
# Matching files found: 20191115T082916_dmi_prep.nc and 20191115T082916_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20191115T082916_resized.nc
# Matching files found: 20200619T122818_cis_prep.nc and 20200619T122818_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20200619T122818_resized.nc
# Matching files found: 20191020T205220_dmi_prep.nc and 20191020T205220_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20191020T205220_resized.nc
# Matching files found: 20210814T211241_dmi_prep.nc and 20210814T211241_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20210814T211241_resized.nc
# Matching files found: 20190807T121817_cis_prep.nc and 20190807T121817_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20190807T121817_resized.nc
# Matching files found: 20201115T105723_dmi_prep.nc and 20201115T105723_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20201115T105723_resized.nc
# Matching files found: 20201112T112057_cis_prep.nc and 20201112T112057_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20201112T112057_resized.nc
# Matching files found: 20211101T085004_dmi_prep.nc and 20211101T085004_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20211101T085004_resized.nc
# Matching files found: 20190525T203543_dmi_prep.nc and 20190525T203543_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20190525T203543_resized.nc
# Matching files found: 20200213T203546_dmi_prep.nc and 20200213T203546_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20200213T203546_resized.nc
# Matching files found: 20190831T130738_cis_prep.nc and 20190831T130738_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20190831T130738_resized.nc
# Matching files found: 20210116T210919_dmi_prep.nc and 20210116T210919_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20210116T210919_resized.nc
# Matching files found: 20210814T211341_dmi_prep.nc and 20210814T211341_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20210814T211341_resized.nc
# Matching files found: 20180922T113859_cis_prep.nc and 20180922T113859_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20180922T113859_resized.nc
# Matching files found: 20190831T144652_cis_prep.nc and 20190831T144652_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20190831T144652_resized.nc
# Matching files found: 20190527T211213_dmi_prep.nc and 20190527T211213_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20190527T211213_resized.nc
# Matching files found: 20200924T211258_dmi_prep.nc and 20200924T211258_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20200924T211258_resized.nc
# Matching files found: 20211206T081020_dmi_prep.nc and 20211206T081020_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20211206T081020_resized.nc
# Matching files found: 20210921T120121_cis_prep.nc and 20210921T120121_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20210921T120121_resized.nc
# Matching files found: 20180826T093044_dmi_prep.nc and 20180826T093044_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20180826T093044_resized.nc
# Matching files found: 20190206T212401_cis_prep.nc and 20190206T212401_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20190206T212401_resized.nc
# Matching files found: 20180424T194715_dmi_prep.nc and 20180424T194715_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20180424T194715_resized.nc
# Matching files found: 20200714T184241_dmi_prep.nc and 20200714T184241_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20200714T184241_resized.nc
# Matching files found: 20210920T210358_dmi_prep.nc and 20210920T210358_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20210920T210358_resized.nc
# Matching files found: 20210116T193108_dmi_prep.nc and 20210116T193108_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20210116T193108_resized.nc
# Matching files found: 20200918T081015_dmi_prep.nc and 20200918T081015_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20200918T081015_resized.nc
# Matching files found: 20210118T075356_dmi_prep.nc and 20210118T075356_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20210118T075356_resized.nc
# Matching files found: 20190812T131548_cis_prep.nc and 20190812T131548_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20190812T131548_resized.nc
# Matching files found: 20190603T210339_dmi_prep.nc and 20190603T210339_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20190603T210339_resized.nc
# Matching files found: 20180903T155253_cis_prep.nc and 20180903T155253_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20180903T155253_resized.nc
# Matching files found: 20200807T153548_cis_prep.nc and 20200807T153548_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20200807T153548_resized.nc
# Matching files found: 20210309T105919_cis_prep.nc and 20210309T105919_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20210309T105919_resized.nc
# Matching files found: 20180325T194759_dmi_prep.nc and 20180325T194759_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20180325T194759_resized.nc
# Matching files found: 20211122T082644_dmi_prep.nc and 20211122T082644_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20211122T082644_resized.nc
# Matching files found: 20210521T082226_dmi_prep.nc and 20210521T082226_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20210521T082226_resized.nc
# Matching files found: 20200925T080407_dmi_prep.nc and 20200925T080407_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20200925T080407_resized.nc
# Matching files found: 20211220T102441_dmi_prep.nc and 20211220T102441_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20211220T102441_resized.nc
# Matching files found: 20210607T082538_dmi_prep.nc and 20210607T082538_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20210607T082538_resized.nc
# Matching files found: 20200920T160733_cis_prep.nc and 20200920T160733_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20200920T160733_resized.nc
# Matching files found: 20201203T082821_dmi_prep.nc and 20201203T082821_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20201203T082821_resized.nc
# Matching files found: 20180923T201918_dmi_prep.nc and 20180923T201918_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20180923T201918_resized.nc
# Matching files found: 20201217T211136_dmi_prep.nc and 20201217T211136_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20201217T211136_resized.nc
# Matching files found: 20210530T102740_cis_prep.nc and 20210530T102740_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20210530T102740_resized.nc
# Matching files found: 20181022T180429_dmi_prep.nc and 20181022T180429_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20181022T180429_resized.nc
# Matching files found: 20210205T214147_cis_prep.nc and 20210205T214147_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20210205T214147_resized.nc
# Matching files found: 20200919T161650_cis_prep.nc and 20200919T161650_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20200919T161650_resized.nc
# Matching files found: 20211015T205240_dmi_prep.nc and 20211015T205240_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20211015T205240_resized.nc
# Matching files found: 20200312T102427_dmi_prep.nc and 20200312T102427_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20200312T102427_resized.nc
# Matching files found: 20190924T144554_cis_prep.nc and 20190924T144554_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20190924T144554_resized.nc
# Matching files found: 20200415T104354_cis_prep.nc and 20200415T104354_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20200415T104354_resized.nc
# Matching files found: 20190216T205218_dmi_prep.nc and 20190216T205218_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20190216T205218_resized.nc
# Matching files found: 20200326T203446_dmi_prep.nc and 20200326T203446_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20200326T203446_resized.nc
# Matching files found: 20201204T211948_dmi_prep.nc and 20201204T211948_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20201204T211948_resized.nc
# Matching files found: 20180421T080346_dmi_prep.nc and 20180421T080346_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20180421T080346_resized.nc
# Matching files found: 20180821T165031_cis_prep.nc and 20180821T165031_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20180821T165031_resized.nc
# Matching files found: 20200124T102732_cis_prep.nc and 20200124T102732_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20200124T102732_resized.nc
# Matching files found: 20210116T193208_dmi_prep.nc and 20210116T193208_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20210116T193208_resized.nc
# Matching files found: 20200807T122136_cis_prep.nc and 20200807T122136_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20200807T122136_resized.nc
# Matching files found: 20210407T101841_cis_prep.nc and 20210407T101841_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20210407T101841_resized.nc
# Matching files found: 20211222T105953_cis_prep.nc and 20211222T105953_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20211222T105953_resized.nc
# Matching files found: 20180427T103155_dmi_prep.nc and 20180427T103155_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20180427T103155_resized.nc
# Matching files found: 20200921T164824_cis_prep.nc and 20200921T164824_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20200921T164824_resized.nc
# Matching files found: 20210429T080105_dmi_prep.nc and 20210429T080105_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20210429T080105_resized.nc
# Matching files found: 20211014T210254_dmi_prep.nc and 20211014T210254_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20211014T210254_resized.nc
# Matching files found: 20200628T205222_dmi_prep.nc and 20200628T205222_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20200628T205222_resized.nc
# Matching files found: 20210912T212151_dmi_prep.nc and 20210912T212151_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20210912T212151_resized.nc
# Matching files found: 20190511T120101_dmi_prep.nc and 20190511T120101_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20190511T120101_resized.nc
# Matching files found: 20210113T101813_dmi_prep.nc and 20210113T101813_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20210113T101813_resized.nc
# Matching files found: 20190807T104254_cis_prep.nc and 20190807T104254_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20190807T104254_resized.nc
# Matching files found: 20190306T102625_cis_prep.nc and 20190306T102625_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20190306T102625_resized.nc
# Matching files found: 20190612T101120_cis_prep.nc and 20190612T101120_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20190612T101120_resized.nc
# Matching files found: 20210628T192300_dmi_prep.nc and 20210628T192300_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20210628T192300_resized.nc
# Matching files found: 20180924T080254_dmi_prep.nc and 20180924T080254_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20180924T080254_resized.nc
# Matching files found: 20180812T130731_cis_prep.nc and 20180812T130731_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20180812T130731_resized.nc
# Matching files found: 20211007T081021_dmi_prep.nc and 20211007T081021_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20211007T081021_resized.nc
# Matching files found: 20190730T123155_cis_prep.nc and 20190730T123155_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20190730T123155_resized.nc
# Matching files found: 20181028T123015_cis_prep.nc and 20181028T123015_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20181028T123015_resized.nc
# Matching files found: 20211014T080213_dmi_prep.nc and 20211014T080213_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20211014T080213_resized.nc
# Matching files found: 20200201T212408_cis_prep.nc and 20200201T212408_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20200201T212408_resized.nc
# Matching files found: 20180821T151146_cis_prep.nc and 20180821T151146_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20180821T151146_resized.nc
# Matching files found: 20210709T085811_dmi_prep.nc and 20210709T085811_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20210709T085811_resized.nc
# Matching files found: 20180829T113858_cis_prep.nc and 20180829T113858_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20180829T113858_resized.nc
# Matching files found: 20211029T203602_dmi_prep.nc and 20211029T203602_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20211029T203602_resized.nc
# Matching files found: 20210520T082720_dmi_prep.nc and 20210520T082720_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20210520T082720_resized.nc
# Matching files found: 20200703T210448_dmi_prep.nc and 20200703T210448_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20200703T210448_resized.nc
# Matching files found: 20200930T080916_dmi_prep.nc and 20200930T080916_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20200930T080916_resized.nc
# Matching files found: 20200930T201936_dmi_prep.nc and 20200930T201936_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20200930T201936_resized.nc
# Matching files found: 20201230T080205_dmi_prep.nc and 20201230T080205_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20201230T080205_resized.nc
# Matching files found: 20200728T120112_cis_prep.nc and 20200728T120112_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20200728T120112_resized.nc
# Matching files found: 20200523T102734_cis_prep.nc and 20200523T102734_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20200523T102734_resized.nc
# Matching files found: 20210426T114547_dmi_prep.nc and 20210426T114547_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20210426T114547_resized.nc
# Matching files found: 20210624T074628_dmi_prep.nc and 20210624T074628_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20210624T074628_resized.nc
# Matching files found: 20190505T102627_cis_prep.nc and 20190505T102627_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20190505T102627_resized.nc
# Matching files found: 20190731T131647_cis_prep.nc and 20190731T131647_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20190731T131647_resized.nc
# Matching files found: 20210519T115303_dmi_prep.nc and 20210519T115303_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20210519T115303_resized.nc
# Matching files found: 20210720T211851_dmi_prep.nc and 20210720T211851_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20210720T211851_resized.nc
# Matching files found: 20190908T205227_dmi_prep.nc and 20190908T205227_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20190908T205227_resized.nc
# Matching files found: 20190304T112814_dmi_prep.nc and 20190304T112814_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20190304T112814_resized.nc
# Matching files found: 20191014T205228_dmi_prep.nc and 20191014T205228_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20191014T205228_resized.nc
# Matching files found: 20211025T085815_dmi_prep.nc and 20211025T085815_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20211025T085815_resized.nc
# Matching files found: 20181118T120459_cis_prep.nc and 20181118T120459_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20181118T120459_resized.nc
# Matching files found: 20180410T214024_cis_prep.nc and 20180410T214024_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20180410T214024_resized.nc
# Matching files found: 20210809T112155_cis_prep.nc and 20210809T112155_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20210809T112155_resized.nc
# Matching files found: 20200928T114452_dmi_prep.nc and 20200928T114452_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20200928T114452_resized.nc
# Matching files found: 20191013T210446_dmi_prep.nc and 20191013T210446_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20191013T210446_resized.nc
# Matching files found: 20180820T120001_dmi_prep.nc and 20180820T120001_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20180820T120001_resized.nc
# Matching files found: 20210113T110732_cis_prep.nc and 20210113T110732_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20210113T110732_resized.nc
# Matching files found: 20180914T115342_cis_prep.nc and 20180914T115342_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20180914T115342_resized.nc
# Matching files found: 20200224T102034_cis_prep.nc and 20200224T102034_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20200224T102034_resized.nc
# Matching files found: 20180721T120156_cis_prep.nc and 20180721T120156_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20180721T120156_resized.nc
# Matching files found: 20190105T102726_cis_prep.nc and 20190105T102726_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20190105T102726_resized.nc
# Matching files found: 20180810T155252_cis_prep.nc and 20180810T155252_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20180810T155252_resized.nc
# Matching files found: 20190306T102725_cis_prep.nc and 20190306T102725_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20190306T102725_resized.nc
# Matching files found: 20190507T101118_cis_prep.nc and 20190507T101118_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20190507T101118_resized.nc
# Matching files found: 20201026T070429_dmi_prep.nc and 20201026T070429_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20201026T070429_resized.nc
# Matching files found: 20200910T194821_dmi_prep.nc and 20200910T194821_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20200910T194821_resized.nc
# Matching files found: 20181028T114104_cis_prep.nc and 20181028T114104_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20181028T114104_resized.nc
# Matching files found: 20190808T120918_cis_prep.nc and 20190808T120918_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20190808T120918_resized.nc
# Matching files found: 20181029T201919_dmi_prep.nc and 20181029T201919_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20181029T201919_resized.nc
# Matching files found: 20201007T210352_dmi_prep.nc and 20201007T210352_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20201007T210352_resized.nc
# Matching files found: 20180607T184226_dmi_prep.nc and 20180607T184226_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20180607T184226_resized.nc
# Matching files found: 20191212T210345_dmi_prep.nc and 20191212T210345_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20191212T210345_resized.nc
# Matching files found: 20191012T081214_dmi_prep.nc and 20191012T081214_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20191012T081214_resized.nc
# Matching files found: 20210824T114554_dmi_prep.nc and 20210824T114554_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20210824T114554_resized.nc
# Matching files found: 20210528T113129_cis_prep.nc and 20210528T113129_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20210528T113129_resized.nc
# Matching files found: 20180222T101622_dmi_prep.nc and 20180222T101622_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20180222T101622_resized.nc
# Matching files found: 20210919T211043_dmi_prep.nc and 20210919T211043_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20210919T211043_resized.nc
# Matching files found: 20210615T211138_dmi_prep.nc and 20210615T211138_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20210615T211138_resized.nc
# Matching files found: 20210611T120212_dmi_prep.nc and 20210611T120212_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20210611T120212_resized.nc
# Matching files found: 20211130T211142_dmi_prep.nc and 20211130T211142_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20211130T211142_resized.nc
# Matching files found: 20201012T130746_cis_prep.nc and 20201012T130746_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20201012T130746_resized.nc
# Matching files found: 20200312T102631_cis_prep.nc and 20200312T102631_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20200312T102631_resized.nc
# Matching files found: 20200124T102428_dmi_prep.nc and 20200124T102428_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20200124T102428_resized.nc
# Matching files found: 20190607T082058_dmi_prep.nc and 20190607T082058_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20190607T082058_resized.nc
# Matching files found: 20210522T201930_dmi_prep.nc and 20210522T201930_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20210522T201930_resized.nc
# Matching files found: 20180808T075536_dmi_prep.nc and 20180808T075536_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20180808T075536_resized.nc
# Matching files found: 20211108T120121_dmi_prep.nc and 20211108T120121_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20211108T120121_resized.nc
# Matching files found: 20190709T121404_cis_prep.nc and 20190709T121404_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20190709T121404_resized.nc
# Matching files found: 20190317T103300_dmi_prep.nc and 20190317T103300_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20190317T103300_resized.nc
# Matching files found: 20181009T181132_dmi_prep.nc and 20181009T181132_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20181009T181132_resized.nc
# Matching files found: 20210609T211127_dmi_prep.nc and 20210609T211127_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20210609T211127_resized.nc
# Matching files found: 20210919T153556_cis_prep.nc and 20210919T153556_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20210919T153556_resized.nc
# Matching files found: 20200904T082638_dmi_prep.nc and 20200904T082638_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20200904T082638_resized.nc
# Matching files found: 20190117T111531_cis_prep.nc and 20190117T111531_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20190117T111531_resized.nc
# Matching files found: 20201210T212044_dmi_prep.nc and 20201210T212044_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20201210T212044_resized.nc
# Matching files found: 20191013T152820_cis_prep.nc and 20191013T152820_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20191013T152820_resized.nc
# Matching files found: 20210726T202749_dmi_prep.nc and 20210726T202749_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20210726T202749_resized.nc
# Matching files found: 20181104T122313_cis_prep.nc and 20181104T122313_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20181104T122313_resized.nc
# Matching files found: 20210127T212142_dmi_prep.nc and 20210127T212142_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20210127T212142_resized.nc
# ...
# Matching files found: 20181006T130024_cis_prep.nc and 20181006T130024_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20181006T130024_resized.nc
# Matching files found: 20210103T171353_dmi_prep.nc and 20210103T171353_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20210103T171353_resized.nc
# Matching files found: 20210727T104206_cis_prep.nc and 20210727T104206_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20210727T104206_resized.nc
# Matching files found: 20180503T183525_dmi_prep.nc and 20180503T183525_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20180503T183525_resized.nc
# Matching files found: 20200825T081014_dmi_prep.nc and 20200825T081014_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20200825T081014_resized.nc
# Matching files found: 20200129T080358_dmi_prep.nc and 20200129T080358_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20200129T080358_resized.nc
# Matching files found: 20200704T111639_cis_prep.nc and 20200704T111639_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20200704T111639_resized.nc
# Matching files found: 20191006T122020_cis_prep.nc and 20191006T122020_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20191006T122020_resized.nc
# Matching files found: 20201106T121427_cis_prep.nc and 20201106T121427_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20201106T121427_resized.nc
# Matching files found: 20180822T203542_dmi_prep.nc and 20180822T203542_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20180822T203542_resized.nc
# Matching files found: 20190415T211043_dmi_prep.nc and 20190415T211043_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20190415T211043_resized.nc
# Matching files found: 20210710T210250_dmi_prep.nc and 20210710T210250_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20210710T210250_resized.nc
# Matching files found: 20201104T123050_cis_prep.nc and 20201104T123050_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20201104T123050_resized.nc
# Matching files found: 20210301T075448_dmi_prep.nc and 20210301T075448_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20210301T075448_resized.nc
# Matching files found: 20210407T101941_cis_prep.nc and 20210407T101941_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20210407T101941_resized.nc
# Matching files found: 20190503T104149_cis_prep.nc and 20190503T104149_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20190503T104149_resized.nc
# Matching files found: 20210526T105722_dmi_prep.nc and 20210526T105722_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20210526T105722_resized.nc
# Matching files found: 20201222T081805_dmi_prep.nc and 20201222T081805_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20201222T081805_resized.nc
# Matching files found: 20191018T130839_cis_prep.nc and 20191018T130839_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20191018T130839_resized.nc
# Matching files found: 20201104T171455_dmi_prep.nc and 20201104T171455_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20201104T171455_resized.nc
# Matching files found: 20180428T093937_cis_prep.nc and 20180428T093937_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20180428T093937_resized.nc
# Matching files found: 20210819T082114_dmi_prep.nc and 20210819T082114_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20210819T082114_resized.nc
# Matching files found: 20190419T203541_dmi_prep.nc and 20190419T203541_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20190419T203541_resized.nc
# Matching files found: 20190904T132354_cis_prep.nc and 20190904T132354_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20190904T132354_resized.nc
# Matching files found: 20180328T183523_dmi_prep.nc and 20180328T183523_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20180328T183523_resized.nc
# Matching files found: 20180905T130632_cis_prep.nc and 20180905T130632_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20180905T130632_resized.nc
# Matching files found: 20201105T104103_dmi_prep.nc and 20201105T104103_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20201105T104103_resized.nc
# Matching files found: 20210516T211025_dmi_prep.nc and 20210516T211025_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20210516T211025_resized.nc
# Matching files found: 20210215T072003_dmi_prep.nc and 20210215T072003_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20210215T072003_resized.nc
# Matching files found: 20210517T080142_dmi_prep.nc and 20210517T080142_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20210517T080142_resized.nc
# Matching files found: 20180906T080234_dmi_prep.nc and 20180906T080234_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20180906T080234_resized.nc
# Matching files found: 20180806T184330_dmi_prep.nc and 20180806T184330_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20180806T184330_resized.nc
# Matching files found: 20190823T114541_cis_prep.nc and 20190823T114541_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20190823T114541_resized.nc
# Matching files found: 20181004T154442_cis_prep.nc and 20181004T154442_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20181004T154442_resized.nc
# Matching files found: 20181212T205512_dmi_prep.nc and 20181212T205512_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20181212T205512_resized.nc
# Matching files found: 20190409T211011_dmi_prep.nc and 20190409T211011_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20190409T211011_resized.nc
# Matching files found: 20180311T111524_cis_prep.nc and 20180311T111524_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20180311T111524_resized.nc
# Matching files found: 20210129T103213_dmi_prep.nc and 20210129T103213_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20210129T103213_resized.nc
# Matching files found: 20211206T211031_dmi_prep.nc and 20211206T211031_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20211206T211031_resized.nc
# Matching files found: 20190728T205217_dmi_prep.nc and 20190728T205217_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20190728T205217_resized.nc
# Matching files found: 20180306T101622_dmi_prep.nc and 20180306T101622_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20180306T101622_resized.nc
# Matching files found: 20190819T121818_cis_prep.nc and 20190819T121818_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20190819T121818_resized.nc
# Matching files found: 20210901T211131_dmi_prep.nc and 20210901T211131_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20210901T211131_resized.nc
# Matching files found: 20210816T205443_dmi_prep.nc and 20210816T205443_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20210816T205443_resized.nc
# Matching files found: 20190127T113114_cis_prep.nc and 20190127T113114_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20190127T113114_resized.nc
# Matching files found: 20180531T122930_cis_prep.nc and 20180531T122930_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20180531T122930_resized.nc
# Matching files found: 20201223T121824_dmi_prep.nc and 20201223T121824_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20201223T121824_resized.nc
# Matching files found: 20210813T193929_dmi_prep.nc and 20210813T193929_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20210813T193929_resized.nc
# Matching files found: 20190924T130739_cis_prep.nc and 20190924T130739_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20190924T130739_resized.nc
# Matching files found: 20180621T214028_cis_prep.nc and 20180621T214028_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20180621T214028_resized.nc
# Matching files found: 20210701T082840_dmi_prep.nc and 20210701T082840_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20210701T082840_resized.nc
# Matching files found: 20190228T214134_cis_prep.nc and 20190228T214134_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20190228T214134_resized.nc
# Matching files found: 20201119T070533_dmi_prep.nc and 20201119T070533_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20201119T070533_resized.nc
# Matching files found: 20191028T132359_cis_prep.nc and 20191028T132359_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20191028T132359_resized.nc
# Matching files found: 20210914T080148_dmi_prep.nc and 20210914T080148_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20210914T080148_resized.nc
# Matching files found: 20211015T120121_cis_prep.nc and 20211015T120121_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20211015T120121_resized.nc
# Matching files found: 20211208T102441_dmi_prep.nc and 20211208T102441_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20211208T102441_resized.nc
# Matching files found: 20190912T184444_dmi_prep.nc and 20190912T184444_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20190912T184444_resized.nc
# Matching files found: 20210901T211231_dmi_prep.nc and 20210901T211231_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20210901T211231_resized.nc
# Matching files found: 20190707T212001_dmi_prep.nc and 20190707T212001_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20190707T212001_resized.nc
# Matching files found: 20201007T210248_dmi_prep.nc and 20201007T210248_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20201007T210248_resized.nc
# Matching files found: 20190809T120404_cis_prep.nc and 20190809T120404_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20190809T120404_resized.nc
# Matching files found: 20200809T205232_dmi_prep.nc and 20200809T205232_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20200809T205232_resized.nc
# Matching files found: 20200424T101936_cis_prep.nc and 20200424T101936_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20200424T101936_resized.nc
# Matching files found: 20190813T081112_dmi_prep.nc and 20190813T081112_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20190813T081112_resized.nc
# Matching files found: 20201117T193110_dmi_prep.nc and 20201117T193110_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20201117T193110_resized.nc
# Matching files found: 20211002T210358_dmi_prep.nc and 20211002T210358_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20211002T210358_resized.nc
# Matching files found: 20181102T212609_cis_prep.nc and 20181102T212609_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20181102T212609_resized.nc
# Matching files found: 20201211T210921_dmi_prep.nc and 20201211T210921_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20201211T210921_resized.nc
# Matching files found: 20211119T080313_dmi_prep.nc and 20211119T080313_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20211119T080313_resized.nc
# Matching files found: 20180922T145543_cis_prep.nc and 20180922T145543_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20180922T145543_resized.nc
# Matching files found: 20180926T124301_cis_prep.nc and 20180926T124301_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20180926T124301_resized.nc
# Matching files found: 20210828T205443_dmi_prep.nc and 20210828T205443_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20210828T205443_resized.nc
# Matching files found: 20200927T165045_cis_prep.nc and 20200927T165045_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20200927T165045_resized.nc
# Matching files found: 20200831T211357_dmi_prep.nc and 20200831T211357_resized.nc
# Saved modified file: ai4arctic-sea-ice-challenge-ready-to-train/v2/Cop_Matching/downsampled_sod_modfinal/20200831T211357_resized.nc
# Processing complete.
